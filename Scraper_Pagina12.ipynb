# %% [markdown]
# ## Probando el request y detalles para la página de noticias Página 12

# %%
import requests

# %%
url = 'https://www.pagina12.com.ar/'

# %%
p12 = requests.get(url)

# %%
p12.text
# Out:
# '<!DOCTYPE html><html class="no-js"><head><meta charset="utf-8"><title>Página12 | La otra mirada</title><meta name="google-site-verification" content="x6zSdT0DBcKDmridH4LpEVrCmxcOunR2dgBQVmuL6fg"><script type="application/ld+json">{"@context": "http://schema.org","@type": "Organization","url": "https://www.pagina12.com.ar","logo": "https://www.pagina12.com.ar/assets/media/logo_default_p12.png"}</script><meta property="description" name="description" content="Notas focalizadas en el quehacer político de la Argentina."><meta property="fb:pages" name="fb:pages" content="1541638399393436"><meta property="og:locale" name="og:locale" content="es_AR"><meta property="og:title" name="og:title" content="Página12 | La otra mirada"><meta property="og:site_name" name="og:site_name" content="PAGINA12"><meta property="og:type" name="og:type" content="website"><meta property="og:url" name="og:url" content="https://www.pagina12.com.ar"><meta property="og:description" name="og:description" content="Notas focalizadas en el quehacer político de la Argentina."><meta property="twitter:title" name="twitter:title" content="Página12 | La otra mirada"><meta property="twitter:description" name="twitter:description" content="Notas focalizadas en el quehacer político de la Argentina."><meta property="twitter:creator" name="twitter:creator" content="@Pagina12"><meta property="twitter:site" name="twitter:site" content="@pagina12"><meta property="article:author" name="article:author" content="Página12"><meta property="article:publisher" name="article:publisher" content="https://www.facebook.com/Pagina12ok"><meta name="share_cdn_host" content="https://www.pagina12.com.ar"><meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1, user-scalable=yes" /><link rel="stylesheet" type="text/css" href="//cdn.jsdelivr.net/jquery.slick/1.6.0/slick.css"><link href="https://maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet" type="text/css" crossorigin><link rel="stylesheet" href="https://www.pagina12.com.ar/assets/css/main.min.css?v=1.0.247" media="screen"><link rel="stylesheet" href="https://www.pagina12.com.ar/assets/css/print.min.css?v=1.0.247" media="print"><link rel="shortcut icon" href="https://www.pagina12.com.ar/favicon.ico?v=1.0.247" type="image/x-icon"><link rel="icon" href="https://www.pagina12.com.ar/favicon.ico?v=1.0.247" type="image/x-icon"><link rel="apple-touch-icon" sizes="57x57" href="https://www.pagina12.com.ar/assets/media/favicon/57x57.png?v=1.0.247"><link rel="apple-touch-icon" sizes="72x72" href="https://www.pagina12.com.ar/assets/media/favicon/72x72.png?v=1.0.247"><link rel="apple-touch-icon" sizes="114x114" href="https://www.pagina12.com.ar/assets/media/favicon/114x114.png?v=1.0.247"><link rel="apple-touch-icon" sizes="120x120" href="https://www.pagina12.com.ar/assets/media/favicon/120x120.png?v=1.0.247"><link rel="apple-touch-icon" sizes="144x144" href="https://www.pagina12.com.ar/assets/media/favicon/144x144.png?v=1.0.247"><link rel="apple-touch-icon" sizes="152x152" href="https://www.pagina12.com.ar/assets/media/favicon/152x152.png?v=1.0.247"><script>dataLayer = [];dataLayer.push({"section": "home"});dataLayer.push({"suplement": "home"});dataLayer.push({"listing": "home"});dataLayer.push({"search": "-"});dataLayer.push({"author": "-"});dataLayer.push({"id": "-"});dataLayer.push({"module": "p12_home"});dataLayer.push({"enviroment": "production"});dataLayer.push({"userLoggedIn": "0"});dataLayer.push({"userContributor": "0"});</script><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\'//www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);})(window,document,\'script\',\'dataLayer\',\'GTM-THCQP5X\');</script><script type=\'text/javascript\'>(function() {var _sf_async_config = window._sf_async_config = ...

# %%
p12.headers
# Out:
# {'Date': 'Fri, 09 Oct 2020 21:13:56 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=d51b4c88644e0080196ec7d727cc20d301602278035; expires=Sun, 08-Nov-20 21:13:55 GMT; path=/; domain=.pagina12.com.ar; HttpOnly; SameSite=Lax', 'Vary': 'Accept-Encoding', 'X-DNS-Prefetch-Control': 'off', 'Strict-Transport-Security': 'max-age=15724800; includeSubDomains', 'X-Download-Options': 'noopen', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '1; mode=block', 'X-ETag': 'W/"6127f-v7bViEAVzJMpR6v0G9jT/MbDd74"', 'X-Backend': 'frontend', 'X-Backend-TTL': '180.000', 'X-Type': 'Dynamic URI', 'Age': '3', 'grace': '86400.000 none', 'ttl': '116.232', 'X-Instance': 'cache-front-prod-varnish-6dd6d7c6bb-p6z8h', 'x-restarts': '0', 'X-Cache': 'HIT (23)', 'CF-Cache-Status': 'DYNAMIC', 'cf-request-id': '05b0cfa9a50000a11ada240200000001', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Server': 'cloudflare', 'CF-RAY': '5dfb1bbc3c10a11a-LIM', 'Content-Encoding': 'gzip'}

# %%
p12.request.headers
# Out:
# {'User-Agent': 'python-requests/2.24.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
p12.request.method
# Out:
# 'GET'

# %%
p12.request.url
# Out:
# 'https://www.pagina12.com.ar/'

# %%
from bs4 import BeautifulSoup

# %%
s = BeautifulSoup(p12.text, 'lxml')

# %%
type(s)
# Out:
# bs4.BeautifulSoup

# %%
print(s.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Página12 | La otra mirada
#   </title>
#   <meta content="x6zSdT0DBcKDmridH4LpEVrCmxcOunR2dgBQVmuL6fg" name="google-site-verification"/>
#   <script type="application/ld+json">
#    {"@context": "http://schema.org","@type": "Organization","url": "https://www.pagina12.com.ar","logo": "https://www.pagina12.com.ar/assets/media/logo_default_p12.png"}
#   </script>
#   <meta content="Notas focalizadas en el quehacer político de la Argentina." name="description" property="description"/>
#   <meta content="1541638399393436" name="fb:pages" property="fb:pages"/>
#   <meta content="es_AR" name="og:locale" property="og:locale"/>
#   <meta content="Página12 | La otra mirada" name="og:title" property="og:title"/>
#   <meta content="PAGINA12" name="og:site_name" property="og:site_name"/>
#   <meta content="website" name="og:type" property="og:type"/>
#   <meta content="https://www.pagina12.com.ar" name="og:url" property="og:url"/>
#   <meta content="Notas focalizadas en el quehacer político de la Argentina." name="og:description" property="og:description"/>
#   <meta content="Página12 | La otra mirada" name="twitter:title" property="twitter:title"/>
#   <meta content="Notas focalizadas en el quehacer político de la Argentina." name="twitter:description" property="twitter:description"/>
#   <meta content="@Pagina12" name="twitter:creator" property="twitter:creator"/>
#   <meta content="@pagina12" name="twitter:site" property="twitter:site"/>
#   <meta content="Página12" name="article:author" property="article:author"/>
#   <meta content="https://www.facebook.com/Pagina12ok" name="article:publisher" property="article:publisher"/>
#   <meta content="https://www.pagina12.com.ar" name="share_cdn_host"/>
#   <meta content="width=device-width, initial-scale=1, minimum-scale=1, user-scalable=yes" name="viewport"/>
#   <link href="//cdn.jsdelivr.net/jquery.slick/1.6.0/slick.css" rel="stylesheet" type="text/css"/>
#   <link crossorigin="" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet" type="text/css"/>
#   <link href="https://www.pagina12.com.ar/assets/css/main.min.css?v=1.0.247" media="screen" rel="stylesheet"/>
#   <link href="https://www.pagina12.com.ar/assets/css/print.min.css?v=1.0.247" media="print" rel="stylesheet"/>
#   <link href="https://www.pagina12.com.ar/favicon.ico?v=1.0.247" rel="shortcut icon" type="image/x-icon"/>
#   <link href="https://www.pagina12.com.ar/favicon.ico?v=1.0.247" rel="icon" type="image/x-icon"/>
#   <link href="https://www.pagina12.com.ar/assets/media/favicon/57x57.png?v=1.0.247" rel="apple-touch-icon" sizes="57x57"/>
#   <link href="https://www.pagina12.com.ar/assets/media/favicon/72x72.png?v=1.0.247" rel="apple-touch-icon" sizes="72x72"/>
#   <link href="https://www.pagina12.com.ar/assets/media/favicon/114x114.png?v=1.0.247" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="https://www.pagina12.com.ar/assets/media/favicon/120x120.png?v=1.0.247" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="https://www.pagina12.com.ar/assets/media/favicon/144x144.png?v=1.0.247" rel="apple-touch-icon" sizes="144x144"/>
#   <link href="https://www.pagina12.com.ar/assets/media/favicon/152x152.png?v=1.0.247" rel="apple-touch-icon" sizes="152x152"/>
#   <script>
#    dataLayer = [];dataLayer.push({"section": "home"});dataLayer.push({"suplement": "home"});dataLayer.push({"listing": "home"});dataLayer.push({"search": "-"});dataLayer.push({"author": "-"});dataLayer.push({"id": "-"});dataLayer.push({"module": "p12_home"});dataLayer.push({"enviroment": "production"});dataLayer.push({"userLoggedIn": "0"});dataLayer.push({"userContributor": "0"});
#   </script>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-THCQP5X');
#   </script>
#   <script type="text/javascript">
#    (function() {var _sf_async_config = window._sf_async_config = (window._sf_async_config || {});_sf_async_config['uid'] = 65120;_sf_async_config['domain'] = 'pagina12.com.ar';_sf_async_config['flickerControl'] = false;_sf_async_config['useCanonical'] = true;_sf_async_config['useCanonicalDomain'] = true;_sf_async_config['noCookies'] = false;_sf_async_config['topStorageDomain'] = 'top_level_domain';_sf_async_config['title'] = document.title;_sf_async_config['sections'] = 'home';_sf_async_config['authors'] = '';_sf_async_config['path'] = window.location.pathname;var _cbq = window._cbq = (window._cbq || []);_cbq.push(['_acct', 'anon']);function loadChartbeat() {var e = document.createElement('script');var n = document.getElementsByTagName('script')[0];e.type = 'text/javascript';e.async = true;e.src = '//static.chartbeat.com/js/chartbeat.js';n.parentNode.insertBefore(e, n);}loadChartbeat();})();
#   </script>
#  </head>
#  <body class="bg-gray">
#   <div class="body-wrapper">
#    <div class="ads-oop">
#     <div id="div-gpt-ad-1503943435188-10">
#     </div>
#    </div>
#    <div class="ads-interstitial">
#     <div class="ad-intrstl" id="div-gpt-ad-1542048685691-0" style="display: none;">
#      <div class="closeBttn" id="div-gpt-ad-1542048685691-0_close">
#      </div>
#     </div>
#    </div>
#    <div class="ads-intersticial">
#     <div id="div-gpt-ad-1594150855223-0">
#     </div>
#    </div>
#    <div class="ads-adhesion">
#     <div id="div-gpt-ad-1594154372667-0">
#     </div>
#    </div>
#    <div class="ads-intersticial">
#     <div id="div-gpt-ad-1594152400889-0">
#     </div>
#    </div>
#    <div class="ads-adhesion">
#     <div id="div-gpt-ad-1594154141807-0">
#     </div>
#    </div>
#    <div class="header-ads banner-wrapper-top">
#     <div class="ads-horizontal-expand show-for-large">
#      <div id="div-gpt-ad-1503943435188-5">
#      </div>
#     </div>
#     <div class="ads-horizontal-expand show-for-medium-only">
#      <div id="div-gpt-ad-1503943435188-13">
#      </div>
#     </div>
#     <div class="text-center banner-wrapper not-expand-empty hide-for-medium">
#      <div id="div-gpt-ad-1503943435188-9">
#      </div>
#     </div>
#    </div>
#    <header class="header">
#     <div class="container">
#      <div class="header-top-content">
#       <div class="left-header-section">
#        <div class="logo-content">
#         <figure class="logo">
#          <a href="https://www.pagina12.com.ar">
#           <img alt="Logo Página 12" height="56" src="https://www.pagina12.com.ar/assets/media/logos/amp/logo_pagina_12_n.svg?v=1.0.247" width="270"/>
#          </a>
#         </figure>
#        </div>
#        <div class="date">
#         <span class="p12-separator--right--gray">
#          09 de octubre de 2020
#         </span>
#         <span class="p12-separator--right--gray is-uppercase">
#          <a href="/edicion-impresa">
#           Edición Impresa
#          </a>
#         </span>
#         <span class="pdf-icon-impresa">
#          <a href="https://auth.pagina12.com.ar/ingresar?redirect=https://www.pagina12.com.ar" target="_top">
#           <i class="fa fa-file-pdf-o">
#           </i>
#           PDF
#          </a>
#         </span>
#        </div>
#       </div>
#       <div class="right-header-section">
#        <div class="header-subscribe-banner">
#         <strong>
#          Defendé la otra mirada
#         </strong>
#         por $300 x mes
#        </div>
#        <div class="user-content">
#         <div class="burger-access">
#          <form action="https://auth.pagina12.com.ar/ingresar?redirect=https://www.pagina12.com.ar" class="login-form" method="post">
#           <input name="redirect" type="hidden" value="https://www.pagina12.com.ar"/>
#           <input name="client" type="hidden" value="hnCJNxS2l9"/>
#           <button class="button button-link is-uppercase" type="submit">
#            <span class="icon">
#             <i aria-hidden="true" class="fa fa-user">
#             </i>
#            </span>
#            <span>
#             Iniciar sesión
#            </span>
#           </button>
#          </form>
#          <a class="button button-highlight is-uppercase" href="https://www.pagina12.com.ar/socies/alta-suscripcion-plan?utm_source=pagina12&amp;utm_medium=amp_burger&amp;utm_campaign=none" target="_blank">
#           <span>
#            Hacete soci@
#           </span>
#           <span class="icon">
#            <i aria-hidden="true" class="fa fa-arrow-right">
#            </i>
#           </span>
#          </a>
#         </div>
#        </div>
#        <button class="button-hamburger" id="hamburger" onclick="jQuery('#mobile-menu').toggleClass('is-active');jQuery('#hamburger').toggleClass('is-active')" tabindex="2">
#         <span>
#         </span>
#         <span>
#         </span>
#         <span>
#         </span>
#        </button>
#       </div>
#      </div>
#      <div class="header-bottom-content mobile-menu" id="mobile-menu">
#       <div class="user-content-mobile mobile-menu-section">
#        <div class="user-options">
#         <form action="https://auth.pagina12.com.ar/ingresar?redirect=https://www.pagina12.com.ar" method="post">
#          <input name="redirect" type="hidden" value="https://www.pagina12.com.ar"/>
#          <input name="client" type="hidden" value="hnCJNxS2l9"/>
#          <button class="button button-link login" type="submit">
#           <span>
#            Ingresar
#           </span>
#          </button>
#         </form>
#         <a class="button button-highlight membership" href="https://www.pagina12.com.ar/socies/alta-suscripcion-plan?utm_source=pagina12&amp;utm_medium=amp_burger&amp;utm_campaign=none" target="_blank">
#          <span>
#           Hacete soci@
#          </span>
#          <span class="icon">
#           <i aria-hidden="true" class="fa fa-arrow-right">
#           </i>
#          </span>
#         </a>
#        </div>
#       </div>
#       <div class="printed-block mobile-menu-section">
#        <div class="printed-menu">
#         <div class="today">
#          09 de octubre de 2020
#         </div>
#         <div class="todays-edition">
#          <span class="p12-separator--right--gray is-uppercase">
#           <a href="/edicion-impresa">
#            Edición Impresa
#           </a>
#          </span>
#          <span class="pdf-icon-impresa">
#           <a href="/?client=hnCJNxS2l9&amp;redirect=" id="NOTlogged" target="_top">
#            <i class="fa fa-file-pdf-o">
#            </i>
#            PDF
#           </a>
#          </span>
#         </div>
#         <ul class="horizontal-list main-supplements">
#          <li>
#           <span class="today">
#            Hoy:
#           </span>
#          </li>
#          <li class="p12-separator--right--primary">
#           <a href="https://www.pagina12.com.ar/suplementos/soy">
#            Soy
#           </a>
#          </li>
#          <li class="p12-separator--right--primary">
#           <a href="https://www.pagina12.com.ar/suplementos/las12">
#            Las12
#           </a>
#          </li>
#          <li class="">
#           <a href="https://www.pagina12.com.ar/suplementos/no">
#            NO
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <div class="left-header-section mobile-menu-section">
#        <nav class="is-display-flex" id="header-main-nav">
#         <div class="p12-dropdown" id="p12-dropdown-desktop">
#          <div class="p12-dropdown-trigger">
#           <button aria-controls="p12-dropdown-desktop" aria-haspopup="true" class="button button-text">
#            <span class="is-uppercase">
#             Secciones y Suplementos
#            </span>
#            <span class="icon is-small">
#             <svg aria-hidden="true" class="svg-inline--fa fa-angle-down fa-w-10" data-fa-i2svg="" data-icon="angle-down" data-prefix="fas" role="img" viewbox="0 0 320 512" xmlns="http://www.w3.org/2000/svg">
#              <path d="M143 352.3L7 216.3c-9.4-9.4-9.4-24.6 0-33.9l22.6-22.6c9.4-9.4 24.6-9.4 33.9 0l96.4 96.4 96.4-96.4c9.4-9.4 24.6-9.4 33.9 0l22.6 22.6c9.4 9.4 9.4 24.6 0 33.9l-136 136c-9.2 9.4-24.4 9.4-33.8 0z" fill="currentColor">
#              </path>
#             </svg>
#            </span>
#           </button>
#          </div>
#          <div class="p12-dropdown-pane" data-auto-focus="true" data-close-on-click="true" id="main-nav-menu">
#           <div class="p12-dropdown-content">
#            <ul class="horizontal-list main-supplements">
#             <li>
#              <span>
#               Hoy:
#              </span>
#             </li>
#             <li class="p12-separator--right--primary">
#              <a href="https://www.pagina12.com.ar/suplementos/soy">
#               Soy
#              </a>
#             </li>
#             <li class="p12-separator--right--primary">
#              <a href="https://www.pagina12.com.ar/suplementos/las12">
#               Las12
#              </a>
#             </li>
#             <li class="">
#              <a href="https://www.pagina12.com.ar/suplementos/no">
#               NO
#              </a>
#             </li>
#            </ul>
#            <div class="p12-dropdown-column">
#             <div class="p12-dropdown-item p12-dropdown-item--header">
#              Secciones
#             </div>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/el-pais">
#              El país
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/economia">
#              Economía
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/sociedad">
#              Sociedad
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/cultura-y-espectaculos">
#              Espectáculos
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/deportes">
#              Deportes
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/ciencia">
#              Ciencia
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/dialogos">
#              Diálogos
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/el-mundo">
#              El mundo
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/edicion-impresa">
#              Edición impresa
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/universidad-diario">
#              Universidad
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/ajedrez">
#              Ajedrez
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/cultura">
#              Cultura
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/plastica">
#              Plástica
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/psicologia">
#              Psicología
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/hoy">
#              Hoy
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/cartas-de-lectores">
#              Cartas de lectores
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/contratapa">
#              Contratapa
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/audiovisuales">
#              Audiovisuales
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/recordatorios">
#              Recordatorios
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/consumo">
#              Consumo
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/salta12">
#              Salta12
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/podcasts">
#              Podcasts
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/soci@s">
#              Soci@s
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/la-ventana">
#              La ventana
#             </a>
#            </div>
#            <div class="p12-dropdown-column has-margin-on-mobile">
#             <div class="p12-dropdown-item p12-dropdown-item--header">
#              Suplementos
#             </div>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/cash">
#              Cash
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/el-enganche">
#              Enganche
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/radar">
#              Radar
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/turismo">
#              Turismo
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/radar-libros">
#              Radar Libros
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/no">
#              NO
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/soy">
#              Soy
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/las12">
#              Las12
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/universidad">
#              Universidad
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/satira12">
#              Sátira12
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/m2">
#              M2
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/rosario12">
#              Rosario12
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/verano12">
#              Verano12
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/libero">
#              Líbero
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/especiales">
#              Especiales de P12
#             </a>
#            </div>
#            <div class="social">
#             <div class="social-inner is-display-flex space-around">
#              <a href="https://www.facebook.com/Pagina12ok/" rel="me nofollow" target="_blank">
#               <i class="fa fa-facebook">
#               </i>
#              </a>
#              <a href="https://twitter.com/pagina12" rel="me nofollow" target="_blank">
#               <i class="fa fa-twitter">
#               </i>
#              </a>
#              <a href="https://www.instagram.com/pagina12/" rel="me nofollow" target="_blank">
#               <i class="fa fa-instagram">
#               </i>
#              </a>
#              <a href="https://www.youtube.com/channel/UCJNDedOnljCssaiRZqg8-Dg" rel="me nofollow" target="_blank">
#               <i class="fa fa-youtube">
#               </i>
#              </a>
#              <a href="https://t.me/pagina12" rel="me nofollow" target="_blank">
#               <i class="fa fa-telegram">
#               </i>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <ul class="horizontal-list main-sections hide-on-dropdown">
#          <li class="p12-separator--right--primary">
#           <a href="https://www.pagina12.com.ar/secciones/el-pais">
#            El país
#           </a>
#          </li>
#          <li class="p12-separator--right--primary">
#           <a href="https://www.pagina12.com.ar/secciones/economia">
#            Economía
#           </a>
#          </li>
#          <li class="p12-separator--right--primary">
#           <a href="https://www.pagina12.com.ar/secciones/sociedad">
#            Sociedad
#           </a>
#          </li>
#          <li class="no-separator-on-1040 p12-separator--right--primary">
#           <a href="https://www.pagina12.com.ar/suplementos/cultura-y-espectaculos">
#            Cultura y Espectáculos
#           </a>
#          </li>
#          <li class="hide-on-1040 p12-separator--right--primary">
#           <a href="https://www.pagina12.com.ar/secciones/deportes">
#            Deportes
#           </a>
#          </li>
#          <li class="hide-on-1040 p12-separator--right--primary">
#           <a href="https://www.pagina12.com.ar/secciones/el-mundo">
#            El mundo
#           </a>
#          </li>
#          <li class="hide-on-1040">
#           <a href="https://www.pagina12.com.ar/secciones/contratapa">
#            Contratapa
#           </a>
#          </li>
#         </ul>
#         <ul class="horizontal-list main-supplements hide-on-dropdown hide-on-1300">
#          <li>
#           <span>
#            Hoy:
#           </span>
#          </li>
#          <li class="p12-separator--right--primary">
#           <a href="https://www.pagina12.com.ar/suplementos/soy">
#            Soy
#           </a>
#          </li>
#          <li class="p12-separator--right--primary">
#           <a href="https://www.pagina12.com.ar/suplementos/las12">
#            Las12
#           </a>
#          </li>
#          <li class="">
#           <a href="https://www.pagina12.com.ar/suplementos/no">
#            NO
#           </a>
#          </li>
#         </ul>
#        </nav>
#       </div>
#       <div class="right-header-section mobile-menu-section">
#        <div class="search-form">
#         <form action="/buscar" method="GET" target="_top">
#          <input autocomplete="off" class="search-form__query" name="q" placeholder="Buscar..." tabindex="-1" type="text"/>
#          <button type="submit" value="search">
#           <i aria-hidden="true" class="fa fa-search">
#           </i>
#          </button>
#         </form>
#        </div>
#       </div>
#      </div>
#      <div class="wrapper" id="p12-user-menu">
#       <form action="https://auth.pagina12.com.ar/ingresar?redirect=https://www.pagina12.com.ar" class="submenu-trigger usermenu-icon" method="post">
#        <input name="redirect" type="hidden" value="https://www.pagina12.com.ar"/>
#        <input name="client" type="hidden" value="hnCJNxS2l9"/>
#        <button role="button" tabindex="1">
#         <i aria-hidden="true" class="fa fa-user">
#         </i>
#        </button>
#       </form>
#      </div>
#     </div>
#    </header>
#    <div class="page-wrapper">
#     <div class="newsletter" id="newsletter-p12-fullWidth">
#      <div class="newsletter-inner wrapper">
#       <span class="newsletter-close fonticon-close" id="newsletter-close" onclick="dataLayer.push({ 'event':'newsletter-top', 'eventAction':'close' })">
#       </span>
#       <div class="xsmall-12 medium-4 large-6 newsletter-info">
#        <div class="newsletter-title">
#         NEWSLETTER
#        </div>
#        <div class="newsletter-desc">
#         <div class="newsletter-desc-inner" id="newsletter-p12-fullWidth-txt">
#         </div>
#        </div>
#        <div class="newsletter-icon">
#         <img src="https://www.pagina12.com.ar/assets/media/assets/newsletter_img.png"/>
#        </div>
#       </div>
#       <div class="xsmall-12 medium-8 large-6 newsletter-form">
#        <form action="/newsletter-subscribe" id="newsletter-form" method="POST">
#         <div id="newsletter-form-elements">
#          <button id="newsletter-p12-fullWidth-btnTxt" onclick="dataLayer.push({ 'event':'newsletter-top', 'eventAction':'click subscribe btn' })" type="submit">
#          </button>
#          <div class="newsletter-input">
#           <input autocomplete="on" id="email_address" name="email_address" placeholder="Ingresá tu email" type="text"/>
#          </div>
#         </div>
#         <div class="g-recaptcha" data-sitekey="6Ldm2zQUAAAAAE-LWT-VH3OQlNEb6pUbaUF4oZak" id="newsletter-recaptcha" style="">
#         </div>
#         <div id="newsletter-loading">
#          <img src="https://www.pagina12.com.ar/assets/media/assets/loading.gif" style="width: 50px;height: 50px;"/>
#         </div>
#         <div id="newsletter-msg">
#         </div>
#        </form>
#       </div>
#      </div>
#     </div>
#     <div class="ventas-full-width" id="ventas-full-width">
#      <div class="ventas-inner wrapper">
#       <img class="ventas-close" id="ventas-close" onclick="dataLayer.push({ 'event':'ventas-top', 'eventAction':'close' })" src="https://www.pagina12.com.ar/assets/media/assets/close-icon.png"/>
#       <div class="xsmall-12 ventas-info">
#        <div class="ventas-logo" data-src="https://www.pagina12.com.ar" id="ventas-logo">
#        </div>
#        <div class="ventas-slogan" id="ventas-slogan">
#        </div>
#        <div class="ventas-btn">
#         <a data-src="https://www.pagina12.com.ar" href="#" id="ventas-btn" onclick="dataLayer.push({ 'event':'ventas-top', 'eventAction':'ir a membresías' })" target="_blank">
#         </a>
#        </div>
#        <div class="ventas-icon" data-src="https://www.pagina12.com.ar" id="ventas-icon">
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="home">
#      <div class="row">
#       <div class="main-wrapper" id="main-wrapper">
#        <div class="wrapper">
#         <div class="layout-region region-1 moderna">
#          <div class="headlines-group">
#           <div class="columns small-12 medium-6 medium-push-3">
#            <div class="headline-card headline-featured-1 moderna">
#             <article>
#              <div class="column reverse">
#               <div class="rows xsmall-12 medium-12">
#                <div class="headline-content">
#                 <div class="article-title">
#                  <a href="https://www.pagina12.com.ar/298026-alberto-fernandez-brindara-detalles-sobre-la-nueva-etapa-del">
#                   <div class="element title-prefix">
#                    Antes del anuncio el Presidente dialoga con Axel Kicillof y Horacio Rodríguez Larreta
#                   </div>
#                   <div class="element title">
#                    Alberto Fernández brindará detalles sobre la nueva etapa del aislamiento
#                   </div>
#                   <div class="element title-suffix">
#                    El mandatario comunicará desde la Casa Rosada las nuevas medidas. Antes convocó a una reunión virtual al gobernador bonaerense y al jefe de Gobierno porteño, quien a su vez dará una conferencia de prensa esta misma tarde para anunciar las aperturas que habrá en la Ciudad de Buenos Aires.
#                   </div>
#                  </a>
#                 </div>
#                 <div class="time-author-wrapper article-ta">
#                 </div>
#                </div>
#               </div>
#               <div class="rows xsmall-12 medium-12">
#                <div class="multimedia-container">
#                 <a href="https://www.pagina12.com.ar/298026-alberto-fernandez-brindara-detalles-sobre-la-nueva-etapa-del">
#                  <div class="intrinsic-container">
#                   <img alt="" class="show-for-small-only" src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-10/111793-reunion_0.jpeg?itok=SJ7Bks46"/>
#                   <img alt="" class="show-for-medium-only" src="https://images.pagina12.com.ar/styles/focal_16_9_960x540/public/2020-10/111793-reunion_0.jpeg?itok=cXozY5-H"/>
#                   <img alt="" class="show-for-large-only" src="https://images.pagina12.com.ar/styles/focal_16_9_960x540/public/2020-10/111793-reunion_0.jpeg?itok=cXozY5-H"/>
#                   <img alt="" class="show-for-xsmall-only" src="https://images.pagina12.com.ar/styles/focal_16_9_300x169/public/2020-10/111793-reunion_0.jpeg?itok=pLiWkhWz"/>
#                   <img alt="" class="show-for-xlarge" src="https://images.pagina12.com.ar/styles/focal_16_9_960x540/public/2020-10/111793-reunion_0.jpeg?itok=cXozY5-H"/>
#                  </div>
#                 </a>
#                </div>
#               </div>
#              </div>
#             </article>
#            </div>
#           </div>
#           <div class="columns small-12 medium-3 medium-pull-6">
#            <div class="row headline-featured-1 white-bg moderna">
#             <div class="headline-card headline-1">
#              <article class="headline-card-inner">
#               <div class="block-multimedia">
#                <div class="multimedia-container">
#                 <a href="https://www.pagina12.com.ar/298059-banco-mundial-la-economia-argentina
="show-for-xsmall-only" src="https://images.pagina12.com.ar/styles/focal_16_9_300x169/public/2020-10/111757-enfermero.jpeg?itok=P9eQm3rm"/>
#                   <img alt="Joan Pons Laplana, un enfermero que está trabajando en Reino Unido. " class="show-for-xlarge" src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-10/111757-enfermero.jpeg?itok=DacsMO2z"/>
#                  </div>
#                 </a>
#                </div>
#               </div>
#               <div class="block-content">
#                <div class="headline-content">
#                 <div class="article-title">
#                  <a href="https://www.pagina12.com.ar/298013-vacuna-de-oxford-un-enfermero-voluntario-dio-positivo-en-cor">
#                   Vacuna de Oxford: un enfermero voluntario dio positivo en
#                   <span class="title-separator">
#                    coronavirus
#                   </span>
#                   <span class="title-prefix">
#                    Se trata del español Joan Pons Laplana
#                   </span>
#                  </a>
#                 </div>
#                 <div class="time-author-wrapper article-ta">
#                 </div>
#                </div>
#               </div>
#              </article>
#             </div>
#            </div>
#            <div class="columns small-12 medium-3">
#             <div class="headline-card headline-1">
#              <article class="headline-card-inner">
#               <div class="block-multimedia">
#                <div class="multimedia-container">
#                 <a href="https://www.pagina12.com.ar/297999-lo-que-se-sabe-de-bennu-el-asteroide-que-podria-chocar-con-l">
#                  <div class="intrinsic-container">
#                   <img alt="Una foto del asteroide Bennu tomada por la sonda OSIRIS-REx de la NASA." class="show-for-small-only" src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-10/111740-bennu-cerca-0.jpg?itok=TPNDSIPC"/>
#                   <img alt="Una foto del asteroide Bennu tomada por la sonda OSIRIS-REx de la NASA." class="show-for-medium-only" src="https://images.pagina12.com.ar/styles/focal_16_9_960x540/public/2020-10/111740-bennu-cerca-0.jpg?itok=8e9PskMh"/>
#                   <img alt="Una foto del asteroide Bennu tomada por la sonda OSIRIS-REx de la NASA." class="show-for-large-only" src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-10/111740-bennu-cerca-0.jpg?itok=TPNDSIPC"/>
#                   <img alt="Una foto del asteroide Bennu tomada por la sonda OSIRIS-REx de la NASA." class="show-for-xsmall-only" src="https://images.pagina12.com.ar/styles/focal_16_9_300x169/public/2020-10/111740-bennu-cerca-0.jpg?itok=6AhSlJvp"/>
#                   <img alt="Una foto del asteroide Bennu tomada por la sonda OSIRIS-REx de la NASA." class="show-for-xlarge" src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-10/111740-bennu-cerca-0.jpg?itok=TPNDSIPC"/>
#                  </div>
#                 </a>
#                </div>
#               </div>
#               <div class="block-content">
#                <div class="headline-content">
#                 <div class="article-title">
#                  <a href="https://www.pagina12.com.ar/297999-lo-que-se-sabe-de-bennu-el-asteroide-que-podria-chocar-con-l">
#                   Lo que se sabe de Bennu, el asteroide que podría chocar con la
#                   <span class="title-separator">
#                    Tierra
#                   </span>
#                   <span class="title-prefix">
#                    Publicaron seis nuevos estudios de la misión de la NASA
#                   </span>
#                  </a>
#                 </div>
#                 <div class="time-author-wrapper article-ta">
#                 </div>
#                </div>
#               </div>
#              </article>
#             </div>
#            </div>
#            <div class="columns small-12 medium-3">
#             <div class="headline-card headline-1">
#              <article class="headline-card-inner">
#               <div class="block-multimedia">
#                <div class="multimedia-container">
#                 <a href="https://www.pagina12.com.ar/297492-la-ultima-bruja-en-ser-quemada">
#                  <div class="intrinsic-container">
#                   <img alt="" class="show-for-small-only" src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-10/111195-cv_0.jpg?itok=xyqHrVK_"/>
#                   <img alt="" class="show-for-medium-only" src="https://images.pagina12.com.ar/styles/focal_16_9_960x540/public/2020-10/111195-cv_0.jpg?itok=UBtzptb7"/>
#                   <img alt="" class="show-for-large-only" src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2020-10/111195-cv_0.jpg?itok=xyqHrVK_"/>
# ...
#            </a>
#           </li>
#           <li>
#            <a href="https://www.youtube.com/channel/UCJNDedOnljCssaiRZqg8-Dg" target="_blank">
#             <img src="https://www.pagina12.com.ar/assets/media/assets/social/youtube-white.svg?v=1.0.247"/>
#            </a>
#           </li>
#           <li>
#            <a href="https://t.me/pagina12" target="_blank">
#             <img src="https://www.pagina12.com.ar/assets/media/assets/social/telegram-white.svg?v=1.0.247"/>
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="large-4 medium-4 small-12 columns header-image">
#          <a href="https://www.pagina12.com.ar">
#           <img src="https://www.pagina12.com.ar/assets/media/assets/Pagina12-Logo-footer_blanco.svg?v=1.0.247"/>
#          </a>
#         </div>
#         <div class="large-4 medium-4 small-12 columns social-media show-for-xsmall hide-for-medium">
#          <ul>
#           <li>
#            <a href="https://www.facebook.com/Pagina12ok/" target="_blank">
#             <img src="https://www.pagina12.com.ar/assets/media/assets/social/facebook-white.svg?v=1.0.247"/>
#            </a>
#           </li>
#           <li>
#            <a href="https://twitter.com/pagina12" target="_blank">
#             <img src="https://www.pagina12.com.ar/assets/media/assets/social/twitter-white.svg?v=1.0.247"/>
#            </a>
#           </li>
#           <li>
#            <a href="https://www.instagram.com/pagina12/" target="_blank">
#             <img src="https://www.pagina12.com.ar/assets/media/assets/social/instagram-white.svg?v=1.0.247"/>
#            </a>
#           </li>
#           <li>
#            <a href="https://www.youtube.com/channel/UCJNDedOnljCssaiRZqg8-Dg" target="_blank">
#             <img src="https://www.pagina12.com.ar/assets/media/assets/social/youtube-white.svg?v=1.0.247"/>
#            </a>
#           </li>
#           <li>
#            <a href="https://t.me/pagina12" target="_blank">
#             <img src="https://www.pagina12.com.ar/assets/media/assets/social/telegram-white.svg?v=1.0.247"/>
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="large-4 medium-4 hide-for-xsmall-only hide-for-small-only columns group">
#          <a href="http://octubre.com" target="_blank">
#           <img src="https://www.pagina12.com.ar/assets/media/assets/Logo-octubre-color-footer.svg?v=1.0.247"/>
#          </a>
#         </div>
#        </div>
#        <div class="large-12 column page-map">
#         <div class="row">
#          <div class="column large-12">
#           <div class="row">
#            <div class="columns medium-6 large-6">
#             <div class="row">
#              <div class="columns large-4 medium-4">
#               <h3 class="hide-for-xsmall-only hide-for-small-only">
#                PÁGINA 12
#               </h3>
#               <ul class="one-column-list">
#                <li>
#                 <a href="https://www.pagina12.com.ar/pagina/Contacto">
#                  Contacto
#                 </a>
#                </li>
#               </ul>
#               <div class="rss">
#                <a href="https://www.pagina12.com.ar/pagina/rss">
#                 <img class="icon icon--icon-small" src="https://www.pagina12.com.ar/assets/media/assets/icon-rss.svg?v=1.0.247"/>
#                 RSS
#                </a>
#               </div>
#              </div>
#              <div class="columns large-8 medium-8 hide-for-xsmall-only hide-for-small-only">
#               <h3>
#                SUPLEMENTOS
#               </h3>
#               <ul class="three-column-list">
#                <li>
#                 <a href="https://www.pagina12.com.ar/suplementos/cash">
#                  Cash
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.pagina12.com.ar/suplementos/el-enganche">
#                  Enganche
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.pagina12.com.ar/suplementos/radar">
#                  Radar
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.pagina12.com.ar/suplementos/turismo">
#                  Turismo
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.pagina12.com.ar/suplementos/radar-libros">
#                  Radar Libros
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.pagina12.com.ar/suplementos/no">
#                  NO
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.pagina12.com.ar/suplementos/soy">
#                  Soy
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.pagina12.com.ar/suplementos/las12">
#                  Las12
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.pagina12.com.ar/suplementos/universidad">
#                  Universidad
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.pagina12.com.ar/suplementos/satira12">
#                  Sátira12
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.pagina12.com.ar/suplementos/m2">
#                  M2
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.pagina12.com.ar/suplementos/rosario12">
#                  Rosario12
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.pagina12.com.ar/suplementos/verano12">
#                  Verano12
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.pagina12.com.ar/suplementos/libero">
#                  Líbero
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.pagina12.com.ar/suplementos/especiales">
#                  Especiales de P12
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </div>
#            </div>
#            <div class="columns large-6 medium-6 hide-for-xsmall-only hide-for-small-only">
#             <h3 class="otros">
#              OTRAS PUBLICACIONES
#             </h3>
#             <ul class="three-column-list otros">
#              <li>
#               <a href="http://radioam750.com.ar">
#                AM|750
#               </a>
#              </li>
#              <li>
#               <a href="https://oktubre.fm">
#                Oktubre FM
#               </a>
#              </li>
#              <li>
#               <a href="http://carasycaretas.org.ar">
#                Caras y Caretas
#               </a>
#              </li>
#              <li>
#               <a href="https://salas.carasycaretas.org.ar/">
#                Caras y Caretas Sala
#               </a>
#              </li>
#              <li>
#               <a href="https://octubretv.com/">
#                Octubre TV
#               </a>
#              </li>
#              <li>
#               <a href="http://www.editorialoctubre.com.ar">
#                Editorial Octubre
#               </a>
#              </li>
#              <li>
#               <a href="http://www.diarioz.com.ar">
#                Diario Z
#               </a>
#              </li>
#              <li>
#               <a href="http://elplanetaurbano.com">
#                El Planeta Urbano
#               </a>
#              </li>
#              <li>
#               <a href="https://fmlike.com.ar/">
#                FM Like
#               </a>
#              </li>
#              <li>
#               <a href="http://www.iso.edu.ar">
#                ISO
#               </a>
#              </li>
#              <li>
#               <a href="http://umet.edu.ar">
#                UMET
#               </a>
#              </li>
#              <li>
#               <a href="http://latinoamericapiensa.com">
#                Latinoamérica Piensa
#               </a>
#              </li>
#              <li>
#               <a href="http://radiomalena.com">
#                Malena FM
#               </a>
#              </li>
#              <li>
#               <a href="https://www.elnueve.com.ar/">
#                El Nueve
#               </a>
#              </li>
#              <li>
#               <a href="https://cluboctubre947.com/">
#                Club 947
#               </a>
#              </li>
#              <li>
#               <a href="https://fmaspen.com/">
#                Aspen 102.3
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#          <div class="show-for-xsmall hide-for-medium small-12 columns">
#           <div class="group">
#            <a href="http://octubre.com" target="_blank">
#             <img src="https://www.pagina12.com.ar/assets/media/assets/Logo-octubre-color-footer.svg?v=1.0.247"/>
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="column large-12">
#         <p class="disclaimer">
#          <span>
#           República Argentina
#          </span>
#          <span>
#           |
#          </span>
#          <span>
#           Todos los derechos reservados
#          </span>
#          <span>
#           |
#          </span>
#          <a href="https://www.pagina12.com.ar/pagina/politica-de-privacidad">
#           Política de privacidad
#          </a>
#          <span>
#           |
#          </span>
#          <a href="https://www.pagina12.com.ar/pagina/terminos-y-condiciones">
#           Términos y Condiciones
#          </a>
#          <span>
#           © 2000-2020 www.pagina12.com.ar
#          </span>
#         </p>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="no-cookies-js no-cookies" id="no-cookies">
#    <div class="no-cookies-js-inner">
#     Tu navegador tiene deshabilitado el uso de Cookies. Algunas funcionalidades de Página/12 necesitan que lo habilites para funcionar. Si no sabés como hacerlo hacé
#     <a href="http://academia.colnodo.apc.org/pluginfile.php/1608/block_html/content/Habilitar%20Cookies.pdf" target="_blank">
#      CLICK AQUÍ
#     </a>
#     <div class="fonticon-close" id="no-cookies-close">
#     </div>
#    </div>
#   </div>
#   <noscript>
#    <div class="no-cookies-js" id="no-js">
#     <div class="no-cookies-js-inner">
#      Tu navegador tiene deshabilitado el uso de Javascript. Muchas de las funcionalidades de Página/12 necesitan que lo habilites para funcionar. Si no sabés como hacerlo hacé
#      <a href="https://enable-javascript.com/es" target="_blank">
#       CLICK AQUÍ
#      </a>
#     </div>
#    </div>
#   </noscript>
#   <script type="text/javascript">
#    (function() {function checkCookie() {/* Quick test if browser has cookieEnabled host property */if (navigator.cookieEnabled) return true;/* Create cookie */document.cookie = "cookietest=1";var ret = document.cookie.indexOf("cookietest=") != -1;/* Delete cookie */document.cookie = "cookietest=1; expires=Thu, 01-Jan-1970 00:00:01 GMT";return ret;}if(!checkCookie()) {var noCookies = document.getElementById('no-cookies');noCookies.style.display = 'block';var noCookiesClose = document.getElementById('no-cookies-close');noCookiesClose.addEventListener('click', function () {noCookies.style.display = 'none';})}})();
#   </script>
#   <!--[if lt IE 9]><script src="https://cdnjs.cloudflare.com/ajax/libs/html5shiv/3.7.3/html5shiv.min.js"></script><![endif]-->
#   <script src="https://www.pagina12.com.ar/assets/js/vendor/vendor.min.js?v=1.0.247" type="text/javascript">
#   </script>
#   <script src="https://www.pagina12.com.ar/assets/js/main.min.js?v=1.0.247" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    $.fn.isInViewport = function() {var elementTop = $(this).offset().top;var elementBottom = elementTop + $(this).outerHeight();var viewportTop = $(window).scrollTop();var viewportBottom = viewportTop + $(window).height();return elementBottom > viewportTop && elementTop < viewportBottom;};
#   </script>
#   <script class="jwplayer-script">
#   </script>
#   <script type="text/javascript">
#    let playing = false;let youtubePlayers = [];function onIframelyReady(e) {const iframely = window.iframely;iframely && iframely.on('iframe-ready', iframe => {handleIframelyVideos(iframe);});}function handleIframelyVideos(iframe) {if (!playerjs) console.warn('Player.js is not enabled');const player = new playerjs.Player(iframe);player.supports('event', 'play') && player.on('play', onVideoPlay);player.supports('event', 'pause') && player.on('pause', onVideoStop);player.supports('event', 'ended') && player.on('ended', onVideoStop);}function onYouTubeIframeAPIReady() {$youtubeEmbeds = $('.article-youtube-embed');$youtubeEmbeds.each(function(_, youtubeEmbed) {const embedId = $(this).attr('id');createYouTubePlayer(embedId);});}function createYouTubePlayer(playerId) {const newPlayer = new YT.Player(playerId, {events: {'onStateChange': onPlayerStateChange}});youtubePlayers.push(newPlayer);}function onPlayerStateChange(event) {playing = youtubePlayers.some((player) => {return player.getPlayerState() === YT.PlayerState.PLAYING;});if (event.data === YT.PlayerState.PLAYING) {onVideoPlay();}if (event.data === YT.PlayerState.PAUSED || event.data === YT.PlayerState.ENDED) {if (!playing) onVideoStop();}}function onVideoPlay() {if (window.reloadPage) {clearInterval(window.reloadPage.timer);window.reloadPage.counter = '5';}}function onVideoStop() {reloadHandler('5')}function reloadHandler(delay) {/*** Refresh common functions (Mobile and Desktop).*/const isMobile = function() {return (navigator.userAgent.match(/(iPad|iPhone)/i) != null || navigator.userAgent.match(/Android/i) != null);};const onEvent = function() {window.location.reload(true);};/*** Refresh functions for Desktop.*/const timerFn = function() {return setInterval(function(t) {if (userHasWrittenAComment()) {return clearInterval(window.reloadPage.timer);}window.reloadPage.counter--;console.log('Reload timeout:', window.reloadPage.counter, 'minutes');if (window.reloadPage.counter <= 0) {onEvent();}}, 60000);};/*** Returns True if the user has written a Talk comment.** Talk saves the comment in the sessionStorage so, in order* to know whether the user has written a comment, we need* to check if talkPymStorage:DraftArea_comment-draft_xxx* has a value.*/const userHasWrittenAComment = function() {const storageKeys = Object.keys(window.sessionStorage || {});return storageKeys.some((storageKey) => {const userHasCommented = /^talkPymStorage:DraftArea_comment-draft_.*/.test(storageKey);if (userHasCommented) {const commentData = window.sessionStorage.getItem(storageKey);const comment = JSON.parse(commentData || '{}');return comment.body ? comment.body.length > 0 : false;}return false;});};const manageEvent = function(e) {if (window.reloadPage.timer) {window.reloadPage.counter = delay;}};const manageMessageEvent = function(e) {const evntData = {};try {evntData = JSON.parse(e.originalEvent.data);} catch (err) { }if (evntData.channel) {manageEvent(e);}};const initRefreshForDesktop = function() {window.reloadPage = {timer: null,counter: delay};const eventList = ['resize','scroll','touchmove'];if (eventList && eventList.length > 0) {eventList.forEach(function(evt) {$(window).on(evt, manageEvent);});}$('.video-embed-field-responsive-video').on('mouseenter', () => clearInterval(window.reloadPage.timer));$('.video-embed-field-responsive-video').on('mouseleave', () => { window.reloadPage.timer = timerFn(); });$(window).on('message', manageMessageEvent);$('video').on('timeupdate', manageEvent);window.reloadPage.timer = timerFn();};/*** Refresh functions for Mobile.*/let lastTimePageWasInactive = undefined;const getHiddenPropertyFromPrefix = function(prefix) {return prefix ? (prefix + 'Hidden') : 'hidden';};const getVisibilityChangeFromPrefix = function(prefix) {return (prefix || '') + 'visibilitychange';};const getPrefix = function() {const browserPrefixes = ['moz', 'ms', 'o', 'webkit'];for (let index = 0; index < browserPrefixes.length; index++) {const prefix = browserPrefixes[index];if (getHiddenPr ...
#   </script>
#  </body>
# </html>

# %%
s.find('ul')
# Out:
# <ul class="horizontal-list main-supplements"><li><span class="today">Hoy:</span></li><li class="p12-separator--right--primary"><a href="https://www.pagina12.com.ar/suplementos/soy">Soy</a></li><li class="p12-separator--right--primary"><a href="https://www.pagina12.com.ar/suplementos/las12">Las12</a></li><li class=""><a href="https://www.pagina12.com.ar/suplementos/no">NO</a></li></ul>

# %%
s.find('ul', attrs={'class': 'hot-sections'})

# %%
s.find('div', attrs={'class': 'p12-dropdown-column'}).find('a',attrs={'class': 'p12-dropdown-item'})
# Out:
# <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/el-pais">El país</a>

# %%
s.find('ul', attrs={'class':'horizontal-list main-sections hide-on-dropdown'}).find_all('a')
# Out:
# [<a href="https://www.pagina12.com.ar/secciones/el-pais">El país</a>,
#  <a href="https://www.pagina12.com.ar/secciones/economia">Economía</a>,
#  <a href="https://www.pagina12.com.ar/secciones/sociedad">Sociedad</a>,
#  <a href="https://www.pagina12.com.ar/suplementos/cultura-y-espectaculos">Cultura y Espectáculos</a>,
#  <a href="https://www.pagina12.com.ar/secciones/deportes">Deportes</a>,
#  <a href="https://www.pagina12.com.ar/secciones/el-mundo">El mundo</a>,
#  <a href="https://www.pagina12.com.ar/secciones/contratapa">Contratapa</a>]

# %%
s.find('div', attrs={'class':'p12-dropdown-column'}).find_all('a')
# Out:
# [<a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/el-pais">El país</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/economia">Economía</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/sociedad">Sociedad</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/cultura-y-espectaculos">Espectáculos</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/deportes">Deportes</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/ciencia">Ciencia</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/dialogos">Diálogos</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/el-mundo">El mundo</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/edicion-impresa">Edición impresa</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/universidad-diario">Universidad</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/ajedrez">Ajedrez</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/cultura">Cultura</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/plastica">Plástica</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/psicologia">Psicología</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/hoy">Hoy</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/cartas-de-lectores">Cartas de lectores</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/contratapa">Contratapa</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/audiovisuales">Audiovisuales</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/recordatorios">Recordatorios</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/consumo">Consumo</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/salta12">Salta12</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/podcasts">Podcasts</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/soci@s">Soci@s</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/la-ventana">La ventana</a>]

# %%
secciones = s.find('div', attrs={'class':'p12-dropdown-column'}).find_all('a')
secciones
# Out:
# [<a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/el-pais">El país</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/economia">Economía</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/sociedad">Sociedad</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/cultura-y-espectaculos">Espectáculos</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/deportes">Deportes</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/ciencia">Ciencia</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/dialogos">Diálogos</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/el-mundo">El mundo</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/edicion-impresa">Edición impresa</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/universidad-diario">Universidad</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/ajedrez">Ajedrez</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/cultura">Cultura</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/plastica">Plástica</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/psicologia">Psicología</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/hoy">Hoy</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/cartas-de-lectores">Cartas de lectores</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/contratapa">Contratapa</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/audiovisuales">Audiovisuales</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/recordatorios">Recordatorios</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/consumo">Consumo</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/salta12">Salta12</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/podcasts">Podcasts</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/soci@s">Soci@s</a>,
#  <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/la-ventana">La ventana</a>]

# %%
seccion = secciones[1]
seccion
# Out:
# <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/economia">Economía</a>

# %%
seccion.get_text()
# Out:
# 'El país'

# %%
seccion.get('href')
# Out:
# 'https://www.pagina12.com.ar/secciones/el-pais'

# %%
links_secciones = [seccion.get('href') for seccion in secciones]
links_secciones
# Out:
# ['https://www.pagina12.com.ar/secciones/el-pais',
#  'https://www.pagina12.com.ar/secciones/economia',
#  'https://www.pagina12.com.ar/secciones/sociedad',
#  'https://www.pagina12.com.ar/suplementos/cultura-y-espectaculos',
#  'https://www.pagina12.com.ar/secciones/deportes',
#  'https://www.pagina12.com.ar/secciones/ciencia',
#  'https://www.pagina12.com.ar/secciones/dialogos',
#  'https://www.pagina12.com.ar/secciones/el-mundo',
#  'https://www.pagina12.com.ar/edicion-impresa',
#  'https://www.pagina12.com.ar/secciones/universidad-diario',
#  'https://www.pagina12.com.ar/secciones/ajedrez',
#  'https://www.pagina12.com.ar/secciones/cultura',
#  'https://www.pagina12.com.ar/secciones/plastica',
#  'https://www.pagina12.com.ar/secciones/psicologia',
#  'https://www.pagina12.com.ar/secciones/hoy',
#  'https://www.pagina12.com.ar/secciones/cartas-de-lectores',
#  'https://www.pagina12.com.ar/secciones/contratapa',
#  'https://www.pagina12.com.ar/secciones/audiovisuales',
#  'https://www.pagina12.com.ar/secciones/recordatorios',
#  'https://www.pagina12.com.ar/secciones/consumo',
#  'https://www.pagina12.com.ar/secciones/salta12',
#  'https://www.pagina12.com.ar/secciones/podcasts',
#  'https://www.pagina12.com.ar/secciones/soci@s',
#  'https://www.pagina12.com.ar/secciones/la-ventana']

# %%
try:
    sec = requests.get(links_secciones[1])
    print(sec)
except Exception as e:
    print("Error en el request")
    print(e)
    print('\n')
# Out:
# <Response [200]>

# %%
sec.status_code
# Out:
# 200

# %%
s_seccion = BeautifulSoup(sec.text,'lxml')

# %%
print(s_seccion.prettify())
# Out:
# <!DOCTYPE html>
# <html amp="" lang="es">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Economía | Página12
#   </title>
#   <!-- DUST PATH: /usr/src/app/src/widgets/fc_jsonLD.dust/ -->
#   <script type="application/ld+json">
#    {"@context": "http://schema.org","@type": "BreadcrumbList","itemListElement": [{"@type": "ListItem","position": 1,"name": "","item": ""},{"@type": "ListItem","position": 2,"name": "","item": ""}]}
#   </script>
#   <script type="application/ld+json">
#    {"@context": "http://schema.org","@type": "NewsArticle","mainEntityOfPage": "","headline": "","isAccessibleForFree": false,"image": {"@type": "ImageObject","url": "","width": "","height": ""},"datePublished": "","dateModified": "","isPartOf": {"@type": ["CreativeWork", "Product"],"name" : "Página 12","productID": "pagina12.com.ar:"},"author": [],"publisher": {"@id": "pagina12.com.ar","@type": "Organization","name": "","logo": {"@type": "ImageObject","url": "","width": "","height": ""}},"description": ""}
#   </script>
#   <!-- DUST PATH: /usr/src/app/node_modules/frontend-core/views/widgets/fc_metatags.dust/ -->
#   <meta content="La economía de la Argentina y el mundo desde la crítica a la lógica dominante.
# " name="description" property="description"/>
#   <meta content="1541638399393436" name="fb:pages" property="fb:pages"/>
#   <meta content="es_AR" name="og:locale" property="og:locale"/>
#   <meta content="Economía | Página12" name="og:title" property="og:title"/>
#   <meta content="PAGINA12" name="og:site_name" property="og:site_name"/>
#   <meta content="website" name="og:type" property="og:type"/>
#   <meta content="https://www.pagina12.com.arhttps://www.pagina12.com.ar/secciones/economia" name="og:url" property="og:url"/>
#   <meta content="La economía de la Argentina y el mundo desde la crítica a la lógica dominante.
# " name="og:description" property="og:description"/>
#   <meta content="Economía | Página12" name="twitter:title" property="twitter:title"/>
#   <meta content="La economía de la Argentina y el mundo desde la crítica a la lógica dominante.
# " name="twitter:description" property="twitter:description"/>
#   <meta content="@Pagina12" name="twitter:creator" property="twitter:creator"/>
#   <meta content="@pagina12" name="twitter:site" property="twitter:site"/>
#   <meta content="Página12" name="article:author" property="article:author"/>
#   <meta content="https://www.facebook.com/Pagina12ok" name="article:publisher" property="article:publisher"/>
#   <meta content="width=device-width,minimum-scale=1,initial-scale=1" name="viewport"/>
#   <meta content="amp" name="cXenseParse:oct-channel"/>
#   <meta content="https://www.pagina12.com.ar/secciones/economia" name="cXenseParse:url"/>
#   <meta content="swg-contributions,swg-smartbox" name="amp-experiments-opt-in"/>
#   <link as="script" href="https://cdn.ampproject.org/v0.js" rel="preload"/>
#   <!-- AMP -->
#   <script async="" src="https://cdn.ampproject.org/v0.js">
#   </script>
#   <meta content="sha384-jjb3Fx4kkja2kDFiIyBWnlXJhLiNhH5XlFDQKxWnau-HfcxNplLeZWTFSVuHTUNy" name="amp-script-src"/>
#   <!-- AMP Analytics -->
#   <script async="" custom-element="amp-analytics" src="https://cdn.ampproject.org/v0/amp-analytics-0.1.js">
#   </script>
#   <!-- AMP Ad -->
#   <script async="" custom-element="amp-ad" src="https://cdn.ampproject.org/v0/amp-ad-0.1.js">
#   </script>
#   <!-- AMP Suscriptions -->
#   <script async="" custom-element="amp-subscriptions" src="https://cdn.ampproject.org/v0/amp-subscriptions-0.1.js">
#   </script>
#   <!-- AMP Subscribe with google -->
#   <script async="" custom-element="amp-subscriptions-google" src="https://cdn.ampproject.org/v0/amp-subscriptions-google-0.1.js">
#   </script>
#   <!-- AMP Form -->
#   <script async="" custom-element="amp-form" src="https://cdn.ampproject.org/v0/amp-form-0.1.js">
#   </script>
#   <!-- Custom CSS -->
#   <style amp-custom="">
#    body,html{font-weight:400;max-width:100%}.flex-container,li,nav li,nav ul,ul{list-style:none}html,p{font-family:"Open Sans",sans-serif,serif;font-size:16px}.primary,a{color:#0089C1}header.header,header.header .container{position:relative}body,html,p{font-family:"Open Sans",sans-serif,serif}.container,footer,input[type=checkbox]{box-sizing:border-box}.button,header.header .header-top-content .right-header-section .header-subscribe-banner .burger-access .link,header.header .header-top-content .right-header-section .user-content .burger-access .link{cursor:pointer}.is-display-inline{display:inline}@media screen and (max-width:768px){.is-display-inline-mobile{display:block}}.horizontal-list,.is-display-flex{display:flex}.is-display-block{display:block}@media screen and (max-width:768px){.is-display-block-mobile,.is-display-flex-mobile{display:block}}.is-flex-grid{display:flex}.is-flex-grid>article,.is-flex-grid>div{flex:1}.flex-container{padding:0;margin:10px 0 0;display:flex;align-items:center}.flex-start{justify-content:flex-start}.flex-end{justify-content:flex-end}.center{justify-content:center}.space-between{justify-content:space-between}.space-around{justify-content:space-around}.space-evenly{justify-content:space-evenly}.v-top{align-items:flex-start}.horizontal-list,.v-center{align-items:center}.v-bot{align-items:flex-end}[class*=is-grid-]{display:grid;gap:31px}[class*=is-grid-][class*="-col2"]{grid-template-columns:repeat(2,1fr)}[class*=is-grid-][class*="-col3"]{grid-template-columns:repeat(3,1fr)}[class*=is-grid-][class*="-col4"]{grid-template-columns:repeat(4,1fr)}[class*=is-grid-][class*="-col5"]{grid-template-columns:repeat(5,1fr)}[class*=is-grid-][class*="-col6"]{grid-template-columns:repeat(6,1fr)}[class*=is-grid-][class*="-col7"]{grid-template-columns:repeat(7,1fr)}[class*=is-grid-][class*="-col8"]{grid-template-columns:repeat(8,1fr)}[class*=is-grid-][class*="-col9"]{grid-template-columns:repeat(9,1fr)}[class*=is-grid-][class*="-col10"]{grid-template-columns:repeat(10,1fr)}[class*=is-grid-][class*="-col11"]{grid-template-columns:repeat(11,1fr)}[class*=is-grid-][class*="-col12"]{grid-template-columns:repeat(12,1fr)}@media screen and (max-width:767px){[class*=is-grid-].grid-mobile-row{grid-template-columns:unset;gap:0}}.hide{display:none}.primary-bg{background-color:#0089C1}.gutter{padding:1.9375rem}.gutter-falf{padding:calc(1.9375rem / 2)}.gutter-small{padding:1.25rem}html{overflow:visible;padding-top:0}body{margin:0;line-height:1.5;color:#1B1B1B;background-color:#F4F4F4;overflow-x:hidden;min-height:100%}input[type=checkbox]{padding:0}figure{margin:0;padding:0}ul{margin-left:0;padding-left:0;margin-top:0;margin-bottom:0}p{letter-spacing:0;line-height:1.6}:focus{outline:0}h2.title-list{font-size:1.9375rem;line-height:2.4375rem;letter-spacing:-1px;font-weight:800;margin:0 0 1.25rem}@media screen and (max-width:768px){h2.title-list{font-size:1.75rem;line-height:1.875rem;letter-spacing:-1.5px;margin-bottom:.625rem}}h3.title-list{font-size:1.9375rem;line-height:2.4375rem;letter-spacing:-1px;font-weight:800;margin:0 0 1.25rem}@media screen and (max-width:768px){h3.title-list{font-size:1.0625rem;line-height:1.1875rem;letter-spacing:-.3px}}h4.title-list{font-size:1.375rem;line-height:1.5625rem;letter-spacing:-.73px;font-weight:800;margin:0}.banner-wrapper-top{display:block;text-align:center;margin:10px auto;max-height:100px;height:100px;min-height:100px}.banner-wrapper-top .ad-wrapper{margin:0 auto;background-color:transparent}header.header{background-color:#FFF;padding-top:1.625rem}header.header .is-uppercase{text-transform:uppercase}header.header a:hover{color:red}header.header .header-top-content{display:flex;justify-content:space-between;width:100%;padding-bottom:10px}@media screen and (max-width:768px){h4.title-list{font-size:1.0625rem;line-height:1.1875rem;letter-spacing:-.3px}header.header{padding-top:0;border-top:1px solid #E4E4E4;border-bottom:1px solid #E4E4E4}header.header .header-top-content{padding:.71875rem 1 ...
# /*# sourceMappingURL=maps/list-landing.min.css.map */
#   </style>
#   <link crossorigin="" href="https://fonts.googleapis.com/css?family=Open+Sans:300,400,600,600i,700,800" rel="stylesheet"/>
#   <link crossorigin="" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet" type="text/css"/>
#   <!-- This boilerplate is mandatory to validate AMP -->
#   <style amp-boilerplate="">
#    body{-webkit-animation:-amp-start 8s steps(1,end) 0s 1 normal both;-moz-animation:-amp-start 8s steps(1,end) 0s 1 normal both;-ms-animation:-amp-start 8s steps(1,end) 0s 1 normal both;animation:-amp-start 8s steps(1,end) 0s 1 normal both}@-webkit-keyframes -amp-start{from{visibility:hidden}to{visibility:visible}}@-moz-keyframes -amp-start{from{visibility:hidden}to{visibility:visible}}@-ms-keyframes -amp-start{from{visibility:hidden}to{visibility:visible}}@-o-keyframes -amp-start{from{visibility:hidden}to{visibility:visible}}@keyframes -amp-start{from{visibility:hidden}to{visibility:visible}}
#   </style>
#   <noscript>
#    <style amp-boilerplate="">
#     body{-webkit-animation:none;-moz-animation:none;-ms-animation:none;animation:none}
#    </style>
#   </noscript>
#   <link href="https://www.pagina12.com.ar" rel="canonical"/>
#   <link href="https://www.pagina12.com.ar" rel="amphtml"/>
#   <script id="amp-subscriptions" type="application/json">
#    {"services": [{"authorizationUrl": "https://www.pagina12.com.ar/socies/google/amp-entitlements","actions": {"login": "https://auth.pagina12.com.ar/ingresar","subscribe": "https://auth.pagina12.com.ar/ingresar","contribute": "https://auth.pagina12.com.ar/ingresar"}}, {"serviceId": "subscribe.google.com"}],"fallbackEntitlement": {"source": "fallback","granted": true,"grantReason": "SUBSCRIBER","data": {"isLoggedIn": false,"isContributor": false}}}
#   </script>
#   <meta content="frontpage" name="cXenseParse:pageclass"/>
#   <!-- Iframe -->
#   <script async="" custom-element="amp-iframe" src="https://cdn.ampproject.org/v0/amp-iframe-0.1.js">
#   </script>
#  </head>
#  <body>
#   <!-- CXENSE  Analytics-->
#   <amp-analytics type="cxense">
#    <script type="application/json">
#     { "vars": { "siteId": "1146423369773940922" } }
#    </script>
#   </amp-analytics>
#   <!-- Google Tag Manager -->
#   <amp-analytics config="https://www.googletagmanager.com/amp.json?id=GTM-MPSQLX4&amp;gtm.url=SOURCE_URL" data-credentials="include">
#   </amp-analytics>
#   <div class="grid-container">
#    <!-- DUST PATH: /usr/src/app/src/templates/partials/amp/header_amp.dust/ -->
#    <div class="banner-wrapper-top">
#     <div class="hide-on-mobile hide-on-tablet">
#      <!-- DUST PATH: /usr/src/app/node_modules/frontend-core/views/widgets/fc_adBanner_amp.dust/ -->
#      <div class="ad-wrapper">
#       <amp-ad data-slot="349353471/p12_listado_970x90v_top_ATF" height="90" type="doubleclick" width="970">
#       </amp-ad>
#      </div>
#     </div>
#     <div class="hide-on-mobile hide-on-desktop">
#      <!-- DUST PATH: /usr/src/app/node_modules/frontend-core/views/widgets/fc_adBanner_amp.dust/ -->
#      <div class="ad-wrapper">
#       <amp-ad data-slot="/349353471/p12_listado_728x90_Top_ATF" height="90" type="doubleclick" width="728">
#       </amp-ad>
#      </div>
#     </div>
#     <div class="hide-on-tablet hide-on-desktop">
#      <!-- DUST PATH: /usr/src/app/node_modules/frontend-core/views/widgets/fc_adBanner_amp.dust/ -->
#      <div class="ad-wrapper">
#       <amp-ad data-slot="/349353471/p12_listado_mobile_320x100_top" height="100" type="doubleclick" width="320">
#       </amp-ad>
#      </div>
#     </div>
#    </div>
#    <header class="header">
#     <div class="container">
#      <!-- top row -->
#      <div class="header-top-content">
#       <!-- left -->
#       <div class="left-header-section">
#        <!-- logo -->
#        <div class="logo-content">
#         <figure class="logo">
#          <a href="https://www.pagina12.com.ar">
#           <amp-img alt="Pagina 12" height="56" layout="responsive" noloading="" src="https://www.pagina12.com.ar/assets/media/logos/amp/logo_pagina_12_n.svg?v=1.0.247" width="270">
#           </amp-img>
#          </a>
#         </figure>
#        </div>
#        <!-- date and links to pdf / edicion impresa -->
#        <div class="date">
#         <span class="p12-separator--right--gray">
#          10 de octubre de 2020
#         </span>
#         <span class="p12-separator--right--gray is-uppercase">
#          <a href="/edicion-impresa">
#           Edición Impresa
#          </a>
#         </span>
#         <!-- DUST PATH: /usr/src/app/src/widgets/p12_pdfEdicionImpresa.dust/ -->
#         <span class="pdf-icon-impresa">
#          <a href="https://www.pagina12.com.ar/pdf-printed-edition" subscriptions-action="none" subscriptions-display="data.isLoggedIn AND data.isContributor">
#           <i class="fa fa-file-pdf-o">
#           </i>
#           PDF
#          </a>
#          <a href="https://www.pagina12.com.ar/socies/" subscriptions-action="none" subscriptions-display="data.isLoggedIn AND NOT data.isContributor">
#           <i class="fa fa-file-pdf-o">
#           </i>
#           PDF
#          </a>
#          <a href="https://auth.pagina12.com.ar/ingresar?redirect=https://www.pagina12.com.arhttps://www.pagina12.com.ar/secciones/economia" subscriptions-action="none" subscriptions-display="NOT data.isLoggedIn" target="_top">
#           <i class="fa fa-file-pdf-o">
#           </i>
#           PDF
#          </a>
#         </span>
#        </div>
#       </div>
#       <!-- right -->
#       <div class="right-header-section">
#        <!-- desktop login -->
#        <div class="header-subscribe-banner" subscriptions-actions="" subscriptions-display="NOT data.isLoggedIn">
#         <strong>
#          Defendé la otra mirada
#         </strong>
#         por $300 x mes
#        </div>
#        <div class="header-subscribe-banner" subscriptions-actions="" subscriptions-display="data.isLoggedIn">
#         <div class="spacer">
#         </div>
#        </div>
#        <div class="user-content">
#         <div class="burger-access" subscriptions-action="none" subscriptions-display="NOT data.isLoggedIn">
#          <button class="button button-link is-uppercase" subscriptions-action="login" subscriptions-display="TRUE">
#           <span class="icon">
#            <i aria-hidden="true" class="fa fa-user">
#            </i>
#           </span>
#           <span>
#            Iniciar sesión
#           </span>
#          </button>
#          <a class="button button-highlight is-uppercase" href="https://www.pagina12.com.ar/socies/alta-suscripcion-plan?utm_source=pagina12&amp;utm_medium=amp_burger&amp;utm_campaign=none" target="_blank">
#           <span>
#            Hacete soci@
#           </span>
#           <span class="icon">
#            <i aria-hidden="true" class="fa fa-arrow-right">
#            </i>
#           </span>
#          </a>
#         </div>
#         <div class="burger-access" subscriptions-action="none" subscriptions-display="data.isLoggedIn">
#          <div class="burger-access">
#           <span class="icon">
#            <i aria-hidden="true" class="fa fa-user">
#            </i>
#           </span>
#           <span class="link" on="tap:p12-user-menu.toggleClass(class='is-active')" role="button" tabindex="3">
#            MI CUENTA
#           </span>
#          </div>
#         </div>
#        </div>
#        <!-- burger -->
#        <button class="button-hamburger submenu-trigger burger-icon" id="hamburger" on="tap:hamburger.toggleClass(class='is-active'),mobile-menu.toggleClass(class='is-active')" tabindex="2">
#         <span>
#         </span>
#         <span>
#         </span>
#         <span>
#         </span>
#        </button>
#       </div>
#      </div>
#      <!-- bottom row -->
#      <div class="header-bottom-content mobile-menu" id="mobile-menu">
#       <!-- -->
#       <div class="user-content-mobile mobile-menu-section">
#        <div class="user-options" subscriptions-actions="" subscriptions-display="NOT data.isLoggedIn">
#         <button class="button button-link login" subscriptions-action="login" subscriptions-display="TRUE">
#          <span>
#           Ingresar
#          </span>
#         </button>
#         <a class="button button-highlight membership" href="https://www.pagina12.com.ar/socies/alta-suscripcion-plan?utm_source=pagina12&amp;utm_medium=amp_burger&amp;utm_campaign=none" target="_blank">
#          <span>
#           Hacete soci@
#          </span>
#          <span class="icon">
#           <i aria-hidden="true" class="fa fa-arrow-right">
#           </i>
#          </span>
#         </a>
#        </div>
#        <div class="burger-access" subscriptions-actions="" subscriptions-display="data.isLoggedIn">
#         <a class="burger-access-logout" href="https://www.pagina12.com.ar/logout-user?redirect=https://www.pagina12.com.ar/secciones/economia" target="_top">
#          Cerrar sesión
#         </a>
#        </div>
#       </div>
#       <div class="printed-block mobile-menu-section">
#        <!-- links to todays suplements -->
#        <div class="printed-menu">
#         <!-- pdf inside menu -->
#         <div class="today">
#          10 de octubre de 2020
#         </div>
#         <div class="todays-edition">
#          <span class="p12-separator--right--gray is-uppercase">
#           <a href="/edicion-impresa">
#            Edición Impresa
#           </a>
#          </span>
#          <!-- DUST PATH: /usr/src/app/src/widgets/p12_pdfEdicionImpresa.dust/ -->
#          <span class="pdf-icon-impresa">
#           <a href="https://www.pagina12.com.ar/pdf-printed-edition" subscriptions-action="none" subscriptions-display="data.isLoggedIn AND data.isContributor">
#            <i class="fa fa-file-pdf-o">
#            </i>
#            PDF
#           </a>
#           <a href="https://www.pagina12.com.ar/socies/" subscriptions-action="none" subscriptions-display="data.isLoggedIn AND NOT data.isContributor">
#            <i class="fa fa-file-pdf-o">
#            </i>
#            PDF
#           </a>
#           <a href="https://auth.pagina12.com.ar/ingresar?redirect=https://www.pagina12.com.arhttps://www.pagina12.com.ar/secciones/economia" subscriptions-action="none" subscriptions-display="NOT data.isLoggedIn" target="_top">
#            <i class="fa fa-file-pdf-o">
#            </i>
#            PDF
#           </a>
#          </span>
#         </div>
#         <ul class="horizontal-list main-supplements">
#          <li>
#           <span class="today">
#            Hoy:
#           </span>
#          </li>
#          <li class="">
#           <a href="https://www.pagina12.com.ar/suplementos/cash">
#            Cash
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <div class="left-header-section mobile-menu-section">
#        <nav class="is-display-flex" id="header-main-nav">
#         <!-- DROPDOWN DESK -->
#         <div class="p12-dropdown" id="p12-dropdown-desktop">
#          <!-- section and supplements submenu -->
#          <div class="p12-dropdown-trigger">
#           <button aria-controls="p12-dropdown-menu" aria-haspopup="true" class="button button-text">
#            <span class="is-uppercase">
#             Secciones y Suplementos
#            </span>
#            <span class="icon is-small">
#             <svg aria-hidden="true" class="svg-inline--fa fa-angle-down fa-w-10" data-fa-i2svg="" data-icon="angle-down" data-prefix="fas" role="img" viewbox="0 0 320 512" xmlns="http://www.w3.org/2000/svg">
#              <path d="M143 352.3L7 216.3c-9.4-9.4-9.4-24.6 0-33.9l22.6-22.6c9.4-9.4 24.6-9.4 33.9 0l96.4 96.4 96.4-96.4c9.4-9.4 24.6-9.4 33.9 0l22.6 22.6c9.4 9.4 9.4 24.6 0 33.9l-136 136c-9.2 9.4-24.4 9.4-33.8 0z" fill="currentColor">
#              </path>
#             </svg>
#             <!-- <i class="fas fa-angle-down" aria-hidden="true"></i> -->
#            </span>
#           </button>
#          </div>
#          <div class="p12-dropdown-pane" id="main-nav-menu">
#           <div class="p12-dropdown-content">
#            <!-- today supplements-->
#            <ul class="horizontal-list main-supplements">
#             <li>
#              <span>
#               Hoy:
#              </span>
#             </li>
#             <li class="">
#              <a href="https://www.pagina12.com.ar/suplementos/cash">
#               Cash
#              </a>
#             </li>
#            </ul>
#            <!-- sections -->
#            <div class="p12-dropdown-column">
#             <div class="p12-dropdown-item p12-dropdown-item--header">
#              Secciones
#             </div>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/el-pais">
#              El país
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/economia">
#              Economía
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/sociedad">
#              Sociedad
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/cultura-y-espectaculos">
#              Espectáculos
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/deportes">
#              Deportes
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/ciencia">
#              Ciencia
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/dialogos">
#              Diálogos
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/el-mundo">
#              El mundo
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/edicion-impresa">
#              Edición impresa
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/universidad-diario">
#              Universidad
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/ajedrez">
#              Ajedrez
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/cultura">
#              Cultura
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/plastica">
#              Plástica
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/psicologia">
#              Psicología
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/hoy">
#              Hoy
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/cartas-de-lectores">
#              Cartas de lectores
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/contratapa">
#              Contratapa
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/audiovisuales">
#              Audiovisuales
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/recordatorios">
#              Recordatorios
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/consumo">
#              Consumo
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/salta12">
#              Salta12
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/podcasts">
#              Podcasts
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/soci@s">
#              Soci@s
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/secciones/la-ventana">
#              La ventana
#             </a>
#            </div>
#            <!-- supplements -->
#            <div class="p12-dropdown-column has-margin-on-mobile">
#             <div class="p12-dropdown-item p12-dropdown-item--header">
#              Suplementos
#             </div>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/cash">
#              Cash
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/el-enganche">
#              Enganche
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/radar">
#              Radar
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/turismo">
#              Turismo
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/radar-libros">
#              Radar Libros
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/no">
#              NO
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/soy">
#              Soy
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/las12">
#              Las12
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/universidad">
#              Universidad
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/satira12">
#              Sátira12
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/m2">
#              M2
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/rosario12">
#              Rosario12
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/verano12">
#              Verano12
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/libero">
#              Líbero
#             </a>
#             <a class="p12-dropdown-item" href="https://www.pagina12.com.ar/suplementos/especiales">
#              Especiales de P12
#             </a>
#            </div>
#            <!-- social icons -->
#            <div class="social">
#             <div class="social-inner is-display-flex space-around">
#              <a href="https://www.facebook.com/Pagina12ok/" rel="me nofollow" target="_blank">
#               <i class="fa fa-facebook">
#               </i>
#              </a>
#              <a href="https://twitter.com/pagina12" rel="me nofollow" target="_blank">
#               <i class="fa fa-twitter">
#               </i>
#              </a>
#              <a href="https://www.instagram.com/pagina12/" rel="me nofollow" target="_blank">
#               <i class="fa fa-instagram">
#               </i>
#              </a>
#              <a href="https://www.youtube.com/channel/UCJNDedOnljCssaiRZqg8-Dg" rel="me nofollow" target="_blank">
#               <i class="fa fa-youtube">
#               </i>
#              </a>
#              <a href="https://t.me/pagina12" rel="me nofollow" target="_blank">
#               <i class="fa fa-telegram">
#               </i>
#              </a>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <!-- DROPDOWN DESK -->
#         <ul class="horizontal-list main-sections hide-on-dropdown">
#          <li class="p12-separator--right--primary">
#           <a href="https://www.pagina12.com.ar/secciones/el-pais">
#            El país
#           </a>
#          </li>
#          <li class="p12-separator--right--primary">
#           <a href="https://www.pagina12.com.ar/secciones/economia">
#            Economía
#           </a>
#          </li>
#          <li class="p12-separator--right--primary">
#           <a href="https://www.pagina12.com.ar/secciones/sociedad">
#            Sociedad
#           </a>
#          </li>
#          <li class="no-separator-on-1040 p12-separator--right--primary">
#           <a href="https://www.pagina12.com.ar/suplementos/cultura-y-espectaculos">
#            Cultura y Espectáculos
#           </a>
#          </li>
#          <li class="hide-on-1040 p12-separator--right--primary">
#           <a href="https://www.pagina12.com.ar/secciones/deportes">
#            Deportes
#           </a>
#          </li>
#          <li class="hide-on-1040 p12-separator--right--primary">
#           <a href="https://www.pagina12.com.ar/secciones/el-mundo">
#            El mundo
#           </a>
#          </li>
#          <li class="hide-on-1040">
#           <a href="https://www.pagina12.com.ar/secciones/contratapa">
#            Contratapa
#           </a>
#          </li>
#         </ul>
#         <ul class="horizontal-list main-supplements hide-on-dropdown hide-on-1300">
#          <li>
#           <span>
#            Hoy:
#           </span>
#          </li>
#          <li class="">
#           <a href="https://www.pagina12.com.ar/suplementos/cash">
#            Cash
#           </a>
#          </li>
#         </ul>
#        </nav>
#       </div>
#       <!-- search -->
#       <div class="right-header-section mobile-menu-section">
#        <div class="search-form">
#         <form action="/buscar" method="GET" target="_top">
#          <input autocomplete="off" class="search-form__query" name="q" placeholder="Buscar..." tabindex="-1" type="text"/>
#          <button class="fonticon-search" type="submit" value="search">
#           <i aria-hidden="true" class="fa fa-search">
#           </i>
#          </button>
#         </form>
#        </div>
#       </div>
#      </div>
#      <!-- user menu -->
#      <div class="wrapper" id="p12-user-menu">
#       <a class="submenu-trigger usermenu-icon" role="button" subscriptions-action="login" subscriptions-display="NOT data.isLoggedIn" tabindex="1">
#        <i aria-hidden="true" class="fa fa-user">
#        </i>
#       </a>
#       <a class="submenu-trigger usermenu-icon" role="button" subscriptions-actions="" subscriptions-display="data.isLoggedIn" tabindex="1">
#        <i aria-hidden="true" class="fa fa-user">
#        </i>
#       </a>
#       <ul class="usermenu-links">
#        <li>
#         <a href="https://www.pagina12.com.ar/socies/menu-socio" target="_blank">
#          Soci@s
#         </a>
#        </li>
#        <li>
#         <a href="https://www.pagina12.com.ar/socies/mi-cuenta" target="_blank">
#          Mi cuenta
#         </a>
#        </li>
#        <li>
#         <a href="https://www.pagina12.com.ar/socies/ayuda" target="_blank">
#          Ayuda
#         </a>
#        </li>
#        <li>
#         <a href="https://www.pagina12.com.ar/socies/terminos-y-condiciones" target="_blank">
#          Términos y condiciones
#         </a>
#        </li>
#        <li>
#         <a href="https://www.pagina12.com.ar/logout-user?redirect=https://www.pagina12.com.ar/secciones/economia">
#          Cerrar Sesión
#         </a>
#        </li>
#       </ul>
#       <ul class="usermenu-links" subscriptions-actions="" subscriptions-display="NOT data.isLoggedIn">
#       </ul>
#      </div>
#     </div>
#    </header>
#   </div>
#   <div class="submenu-overlay" hidden="" id="submenu-overlay" on="tap:p12-user-menu.toggleClass(class='is-active', force=false),burgermenu.hide,usermenu.hide,submenu-overlay.hide" role="button" tabindex="1">
#   </div>
#   <div class="container">
#    <section class="hero-area">
#     <div class="text-section-header">
#      <h1>
#       Economía
#      </h1>
#     </div>
#    </section>
#    <div class="main-content" id="main-content">
#     <section class="top-content" id="top-content">
#      <!-- Hero -->
#      <!-- DUST PATH: /usr/src/app/src/templates/partials/amp/articles/main_article.dust/ -->
#      <article class="article-item article-item--main">
#       <!-- Image -->
#       <div class="article-item__header deco-bar-here">
#        <a href="https://www.pagina12.com.ar/298006-la-ley-de-gondolas-ya-rige-en-provincia">
#         <!-- DUST PATH: /usr/src/app/node_modules/frontend-core/views/widgets/fc_displayImg_amp.dust/ -->
#         <amp-img alt='Las grandes superficies deberán contar con una góndola de "Producción bonaerense". (Fuente: Sandra Cartasso)' class="" height="640" layout="responsive" src="https://images.pagina12.com.ar/styles/focal_3_2_960x640/public/2020-10/111747-12-20b-20cartasso.jpeg?itok=8WgzpBt9" srcset="https://images.pagina12.com.ar/styles/focal_3_2_960x640/public/2020-10/111747-12-20b-20cartasso.jpeg?itok=8WgzpBt9 960w, https://images.pagina12.com.ar/styles/focal_3_2_470x313/public/2020-10/111747-12-20b-20cartasso.jpeg?itok=jOtGLF7q 470w, https://images.pagina12.com.ar/styles/focal_3_2_300x200/public/2020-10/111747-12-20b-20cartasso.jpeg?itok=MiR5dQ-B 300w" width="960">
#         </amp-img>
#         <!-- DUST PATH: /usr/src/app/src/templates/partials/amp/articles/components/multimedia_badge.dust/ -->
#        </a>
#       </div>
#       <div class="article-item__content-footer-wrapper gutter-small deco-bar-here-left is-mobile-top">
#        <div class="article-item__content">
#         <!-- Title -->
#         <h2 class="title-list">
#          <a href="https://www.pagina12.com.ar/298006-la-ley-de-gondolas-ya-rige-en-provincia">
#           La ley de gondolas ya rige en Provincia
#          </a>
#         </h2>
#         <!-- Kicker -->
#         <p>
#          <a href="https://www.pagina12.com.ar/298006-la-ley-de-gondolas-ya-rige-en-provincia">
#           El senado bonaerense aprobó la adhesión a la iniciativa nacional
#          </a>
#         </p>
#        </div>
#        <div class="article-item__footer">
#         <!-- Author -->
#         <div class="author">
#          <span>
#           Por
#          </span>
#          <a href="https://www.pagina12.com.ar/autores/272523-natali-risso">
#           Natalí Risso
#          </a>
#         </div>
#         <!-- Date -->
#         <div class="date">
#          10 de octubre de 2020
#         </div>
#        </div>
#       </div>
#      </article>
#      <div class="ad is-display-flex center">
#       <div class="hide-on-mobile">
#        <!-- DUST PATH: /usr/src/app/node_modules/frontend-core/views/widgets/fc_adBanner_amp.dust/ -->
#        <div class="ad-wrapper">
#         <amp-ad data-slot="/349353471/p12_listado_728x90_Top_ATF" height="90" type="doubleclick" width="728">
#         </amp-ad>
#        </div>
#       </div>
#       <div class="hide-on-tablet hide-on-desktop">
#        <!-- DUST PATH: /usr/src/app/node_modules/frontend-core/views/widgets/fc_adBanner_amp.dust/ -->
#        <div class="ad-wrapper">
#         <amp-ad data-slot="/349353471/p12_listado_mobile_300x250_top" height="250" type="doubleclick" width="300">
#         </amp-ad>
#        </div>
#       </div>
#      </div>
#     </section>
#     <section class="list-content" id="list-content">
#      <!-- Featured Articles -->
#      <!-- DUST PATH: /usr/src/app/src/templates/partials/amp/lists/articles_list.dust/ -->
#      <div class="articles-list is-grid-col2 grid-mobile-row">
#       <!-- DUST PATH: /usr/src/app/src/templates/partials/amp/lists/articles_list_item.dust/ -->
#       <!-- DUST PATH: /usr/src/app/src/templates/partials/amp/articles/featured_article.dust/ -->
#       <article class="article-item article-item--featured">
#        <!-- Image -->
#        <div class="article-item__header">
#         <a href="https://www.pagina12.com.ar/298038-la-aduana-destaco-el-rol-de-las-pymes">
#          <!-- DUST PATH: /usr/src/app/node_modules/frontend-core/views/widgets/fc_displayImg_amp.dust/ -->
#          <amp-img alt="" class="" height="313" layout="responsive" src="https://images.pagina12.com.ar/styles/focal_3_2_470x313/public/2020-10/111767-be2c5d3b-758e-42c4-abc0-581cd7a7c202_0.jpg?itok=C0r9DdDo" srcset="https://images.pagina12.com.ar/styles/focal_3_2_470x313/public/2020-10/111767-be2c5d3b-758e-42c4-abc0-581cd7a7c202_0.jpg?itok=C0r9DdDo 470w, https://images.pagina12.com.ar/styles/focal_3_2_300x200/public/2020-10/111767-be2c5d3b-758e-42c4-abc0-581cd7a7c202_0.jpg?itok=bVXxnYBV 300w, https://images.pagina12.com.ar/styles/focal_3_2_120x80/public/2020-10/111767-be2c5d3b-758e-42c4-abc0-581cd7a7c202_0.jpg?itok=tkm0AHpv 120w" width="470">
#          </amp-img>
#          <!-- DUST PATH: /usr/src/app/src/templates/partials/amp/articles/components/multimedia_badge.dust/ -->
#         </a>
#        </div>
#        <div class="article-item__content-footer-wrapper gutter-small deco-bar-here-top is-mobile-left negative-margin-top">
#         <div class="article-item__content">
#          <!-- Article type -->
#          <!-- Title -->
#          <h3 class="title-list">
#           <a href="https://www.pagina12.com.ar/298038-la-aduana-destaco-el-rol-de-las-pymes">
#            La Aduana destacó el rol de las pymes
#           </a>
#          </h3>
#          <!-- Kicker -->
#          <p class="p12-separator--left--primary">
#           <a href="https://www.pagina12.com.ar/298038-la-aduana-destaco-el-rol-de-las-pymes">
#            Encuentro virtual empresario
#           </a>
#          </p>
#         </div>
#         <!-- Author & Date -->
#         <div class="article-item__footer is-display-block-mobile">
#          <div class="date is-display-inline">
#           10 de octubre de 2020
#          </div>
#         </div>
#        </div>
#       </article>
#       <!-- DUST PATH: /usr/src/app/src/templates/partials/amp/lists/articles_list_item.dust/ -->
#       <!-- DUST PATH: /usr/src/app/src/templates/partials/amp/articles/featured_article.dust/ -->
#       <article class="article-item article-item--featured">
#        <!-- Image -->
#        <div class="article-item__header">
#         <a href="https://www.pagina12.com.ar/298051-el-asociativismo-como-alternativa-frente-a-la-crisis">
#          <!-- DUST PATH: /usr/src/app/node_modules/frontend-core/views/widgets/fc_displayImg_amp.dust/ -->
#          <amp-img alt="1237 organizaciones iniciaron los trámites ante el INAES.  (Fuente: Télam)" class="" height="313" layout="responsive" src="https://images.pagina12.com.ar/styles/focal_3_2_470x313/public/2020-10/111755-12-20a-20telam.jpeg?itok=Aby34zkx" srcset="https://images.pagina12.com.ar/styles/focal_3_2_470x313/public/2020-10/111755-12-20a-20telam.jpeg?itok=Aby34zkx 470w, https://images.pagina12.com.ar/styles/focal_3_2_300x200/public/2020-10/111755-12-20a-20telam.jpeg?itok=dD0dpqIJ 300w, https://images.pagina12.com.ar/styles/focal_3_2_120x80/public/2020-10/111755-12-20a-20telam.jpeg?itok=vbqHyZy0 120w" width="470">
#          </amp-img>
#          <!-- DUST PATH: /usr/src/app/src/templates/partials/amp/articles/components/multimedia_badge.dust/ -->
#         </a>
#        </div>
#        <div class="article-item__content-footer-wrapper gutter-small deco-bar-here-top is-mobile-left negative-margin-top">
#         <div class="article-item__content">
#          <!-- Article type -->
#          <!-- Title -->
#          <h3 class="title-list">
#           <a href="https://www.pagina12.com.ar/298051-el-asociativismo-como-alternativa-frente-a-la-crisis">
#            El asociativismo como alternativa frente a la crisis
#           </a>
#          </h3>
#          <!-- Kicker -->
#          <p class="p12-separator--left--primary">
#           <a href="https://www.pagina12.com.ar/298051-el-asociativismo-como-alternativa-frente-a-la-crisis">
#            Durante la pandemia se crearon 335 cooperativas
#           </a>
#          </p>
#         </div>
#         <!-- Author & Date -->
#         <div class="article-item__footer is-display-block-mobile">
#          <div class="date is-display-inline">
#           10 de octubre de 2020
#          </div>
#         </div>
#        </div>
#       </article>
#      </div>
#      <!-- Regular Articles list (articles with image) -->
#      <!-- DUST PATH: /usr/src/app/src/templates/partials/amp/lists/articles_list.dust/ -->
#      <div class="articles-list">
#       <!-- DUST PATH: /usr/src/app/src/templates/partials/amp/lists/articles_list_item.dust/ -->
#       <!-- DUST PATH: /usr/src/app/src/templates/partials/amp/articles/article_teaser.dust/ -->
#       <article class="article-item article-item--teaser">
#        <!-- Image -->
#        <div class="article-item__header">
#         <a href="https://www.pagina12.com.ar/298059-banco-mundial-la-economia-argentina-caera-12-3-por-ciento-es">
#          <!-- DUST PATH: /usr/src/app/node_modules/frontend-core/views/widgets/fc_displayImg_amp.dust/ -->
#          <amp-img alt="Desde el Banco Mundial afirman que América Latina y el Caribe es la región más golpeada por el coronavirus. (Fuente: AFP)" class="" height="200" layout="responsive" src="https://images.pagina12.com.ar/styles/focal_3_2_300x200/public/2020-10/111811-10-20a-20afp.jpeg?itok=qpP2HxQN" width="300">
#          </amp-img>
#          <!-- DUST PATH: /usr/src/app/src/templates/partials/amp/articles/components/multimedia_badge.dust/ -->
#         </a>
#        </div>
#        <div class="article-item__content-footer-wrapper gutter-small deco-bar-here-left">
#         <div class="article-item__content">
#          <!-- Article type -->
#          <!-- Title and Kicker -->
#          <h4 class="is-display-inline title-list">
#           <a class="" href="https://www.pagina12.com.ar/298059-banco-mundial-la-economia-argentina-caera-12-3-por-ciento-es">
#            Banco Mundial: la economía argentina caerá 12,3 por ciento este año
#           </a>
#          </h4>
#          <p class="is-display-inline">
#           <a class="p12-separator--left--primary" href="https://www.pagina12.com.ar/298059-banco-mundial-la-economia-argentina-caera-12-3-por-ciento-es">
#            La baja promedio de América Latina y el Caribe será de 7,9 por ciento
#           </a>
#          </p>
#          <!-- DUST PATH: /usr/src/app/src/templates/partials/amp/articles/components/multimedia_badge.dust/ -->
#         </div>
#         <!-- Authors & Date -->
#         <div class="article-item__footer">
#          <div class="author is-display-inline p12-separator-right-gray">
#           <span>
#            Por
#           </span>
#           <a href="https://www.pagina12.com.ar/autores/204465-florencia-barragan">
#            Florencia Barragan
#           </a>
#          </div>
#          <div class="date is-display-inline">
#           10 de octubre de 2020
#          </div>
#         </div>
#         <!-- DUST PATH: /usr/src/app/src/templates/partials/amp/lists/articles_list_item.dust/ -->
#         <!-- DUST PATH: /usr/src/app/src/templates/partials/amp/articles/article_teaser.dust/ -->
#         <article class="article-item article-item--teaser">
#          <!-- Image -->
#          <div class="article-item__header">
#           <a href="https://www.pagina12.com.ar/298084-round-de-conocimiento-y-autocritica">
#            <!-- DUST PATH: /usr/src/app/node_modules/frontend-core/views/widgets/fc_displayImg_amp.dust/ -->
#            <amp-img alt="Guzmán, Pesce y Chodos, en una de las reuniones de esta semana" class="" height="200" layout="responsive" src="https://images.pagina12.com.ar/styles/focal_3_2_300x200/public/2020-10/111869-7d74d715-bfb9-447a-abe9-efa130ac7f54_0.jpg?itok=Vm19srcu" width="300">
#            </amp-img>
#            <!-- DUST PATH: /usr/src/app/src/templates/partials/amp/articles/components/multimedia_badge.dust/ -->
#           </a>
#          </div>
#          <div class="article-item__content-footer-wrapper gutter-small deco-bar-here-left">
#           <div class="article-item__content">
#            <!-- Article type -->
#            <!-- Title and Kicker -->
#            <h4 class="is-display-inline title-list">
#             <a class="" href="https://www.pagina12.com.ar/298084-round-de-conocimiento-y-autocritica">
#              Round de conocimiento y autocrítica
#             </a>
#            </h4>
#            <p class="is-display-inline">
#             <a class="p12-separator--left--primary" href="https://www.pagina12.com.ar/298084-round-de-conocimiento-y-autocritica">
#              Cierre de la misión argentina del FMI
#             </a>
#            </p>
#            <!-- DUST PATH: /usr/src/app/src/templates/partials/amp/articles/components/multimedia_badge.dust/ -->
#           </div>
#           <!-- Authors & Date -->
#           <div class="article-item__footer">
#            <div class="author is-display-inline p12-separator-right-gray">
#             <span>
#              Por
#             </span>
#             <a class="no-link">
#              Leandro Renou
#             </a>
#            </div>
#            <div class="date is-display-inline">
#             10 de octubre de 2020
#            </div>
#           </div>
#           <!-- DUST PATH: /usr/src/app/src/templates/partials/amp/lists/articles_list_item.dust/ -->
#           <!-- DUST PATH: /usr/src/app/src/templates/partials/amp/articles/article_teaser.dust/ -->
#           <article class="article-item article-item--teaser">
#            <!-- Image -->
#            <div class="article-item__header">
#             <a href="https://www.pagina12.com.ar/298096-crece-la-liquidacion-de-exportaciones">
#              <!-- DUST PATH: /usr/src/app/node_modules/frontend-core/views/widgets/fc_displayImg_amp.dust/ -->
#              <amp-img alt="" class="" height="200" layout="responsive" src="https://images.pagina12.com.ar/styles/focal_3_2_300x200/public/2020-10/111909-soja.jpg?itok=q7ysIq8Z" width="300">
#              </amp-img>
#              <!-- DUST PATH: /usr/src/app/src/templates/partials/amp/articles/components/multimedia_badge.dust/ -->
#             </a>
#            </div>
#            <div class="article-item__content-footer-wrapper gutter-small deco-bar-here-left">
#             <div class="article-item__content">
#              <!-- Article type -->
#              <!-- Title and Kicker -->
#              <h4 class="is-display-inline title-list">
#               <a class="" href="https://www.pagina12.com.ar/298096-crece-la-liquidacion-de-exportaciones">
#                Crece la liquidación de exportaciones
#               </a>
#              </h4>
#              <p class="is-display-inline">
#               <a class="p12-separator--left--primary" href="https://www.pagina12.com.ar/298096-crece-la-liquidacion-de-exportaciones">
#                Aumentó luego de los anuncios oficiales
#               </a>
#              </p>
#              <!-- DUST PATH: /usr/src/app/src/templates/partials/amp/articles/components/multimedia_badge.dust/ -->
#             </div>
#             <!-- Authors & Date -->
#             <div class="article-item__footer">
#              <div class="date is-display-inline">
#               10 de octubre de 2020
#              </div>
#             </div>
#             <!-- DUST PATH: /usr/src/app/src/templates/partials/amp/lists/articles_list_item.dust/ -->
#             <!-- DUST PATH: /usr/src/app/src/templates/partials/amp/articles/article_teaser.dust/ -->
#             <article class="article-item article-item--teaser">
#              <!-- Image -->
#              <div class="article-item__header">
#               <a href="https://www.pagina12.com.ar/298132-a-la-mesa-le-falta-una-pata">
#                <!-- DUST PATH: /usr/src/app/node_modules/frontend-core/views/widgets/fc_displayImg_amp.dust/ -->
#                <amp-img alt='"Nuestra definición es que estamos afuera", dijo Pelegrina, de SRA. ' class="" height="200" layout="responsive" src="https://images.pagina12.com.ar/styles/focal_3_2_300x200/public/2020-10/111950-9d36f3f0-89c5-4a08-bcb3-c6fb23d79946_0.jpg?itok=ClcJWFuO" width="300">
#                </amp-img>
#                <!-- DUST PATH: /usr/src/app/src/templates/partials/amp/articles/components/multimedia_badge.dust/ -->
#               </a>
#              </div>
#              <div class="article-item__content-footer-wrapper gutter-small deco-bar-here-left">
#               <div class="article-item__content">
#                <!-- Article type -->
#                <!-- Title and Kicker -->
#                <h4 class="is-display-inline title-list">
#                 <a class="" href="https://www.pagina12.com.ar/298132-a-la-mesa-le-falta-una-pata">
#                  A la Mesa le falta una pata
#                 </a>
#                </h4>
#                <p class="is-display-inline">
#                 <a class="p12-separator--left--primary" href="https://www.pagina12.com.ar/298132-a-la-mesa-le-falta-una-pata">
#                  La convocatoria del Gobierno divide al campo
#                 </a>
#                </p>
#                <!-- DUST PATH: /usr/src/app/src/templates/partials/amp/articles/components/multimedia_badge.dust/ -->
#               </div>
#               <!-- Authors & Date -->
#               <div class="article-item__footer">
#                <div class="author is-display-inline p12-separator-right-gray">
#                 <span>
#                  Por
#                 </span>
#                 <a class="no-link">
#                  Leandro Renou
#                 </a>
#                </div>
#                <div class="date is-display-inline">
#                 10 de octubre de 2020
#                </div>
#               </div>
#               <div class="ad is-display-flex center">
#                <div class="hide-on-mobile">
# ...
#                       <div class="articles-list-pager">
#                        <nav aria-label="Articles list pagination">
#                         <a class="next" href="/secciones/economia?page=1">
#                          Siguiente página
#                         </a>
#                        </nav>
#                       </div>
#                      </div>
#                      <div class="ad is-display-flex center">
#                       <div class="hide-on-mobile">
#                        <!-- DUST PATH: /usr/src/app/node_modules/frontend-core/views/widgets/fc_adBanner_amp.dust/ -->
#                        <div class="ad-wrapper">
#                         <amp-ad data-slot="/349353471/p12_listado_728x90_BTF_BOTTOM" height="90" type="doubleclick" width="728">
#                         </amp-ad>
#                        </div>
#                       </div>
#                       <div class="hide-on-tablet hide-on-desktop">
#                        <!-- DUST PATH: /usr/src/app/node_modules/frontend-core/views/widgets/fc_adBanner_amp.dust/ -->
#                        <div class="ad-wrapper">
#                         <amp-ad data-slot="/349353471/p12_listado_mobile_300x250_bottom" height="250" type="doubleclick" width="300">
#                         </amp-ad>
#                        </div>
#                       </div>
#                      </div>
#                      <section class="sidebar" id="sidebar">
#                       <div class="ad is-display-flex center" subscriptions-actions="" subscriptions-display="NOT granted">
#                        <!-- DUST PATH: /usr/src/app/node_modules/frontend-core/views/widgets/fc_adBanner_amp.dust/ -->
#                        <div class="ad-wrapper">
#                         <amp-ad data-slot="/349353471/p12_listado_300x250_top_ATF" height="250" type="doubleclick" width="300">
#                         </amp-ad>
#                        </div>
#                       </div>
#                       <!-- DUST PATH: /usr/src/app/src/templates/partials/amp/cxense_sections_lists_sidebar.dust/ -->
#                       <div class="cxense-recommendations-iframe-wrapper">
#                        <amp-iframe frameborder="0" height="500" resizable="" sandbox="allow-scripts allow-same-origin allow-top-navigation" src="https://aw.pagina12.com.ar/amp-cxense-widget/sections-lists-sidebar" width="auto">
#                         <div placeholder="">
#                          <svg fill="none" height="221" preserveaspectratio="none" viewbox="0 0 373 221" width="600" xmlns="http://www.w3.org/2000/svg">
#                           <rect fill="#E2E2E2" height="130" width="145" x="10" y="10">
#                           </rect>
#                           <rect fill="#E2E2E2" height="130" width="140" x="170" y="10">
#                           </rect>
#                           <rect fill="#E2E2E2" height="130" width="140" x="325" y="10">
#                           </rect>
#                           <rect fill="#E2E2E2" height="15" width="140" x="10" y="145">
#                           </rect>
#                           <rect fill="#E2E2E2" height="15" width="125" x="10" y="165">
#                           </rect>
#                           <rect fill="#E2E2E2" height="15" width="135" x="10" y="185">
#                           </rect>
#                           <rect fill="#E2E2E2" height="15" width="140" x="10" y="205">
#                           </rect>
#                           <rect fill="#E2E2E2" height="15" width="140" x="170" y="145">
#                           </rect>
#                           <rect fill="#E2E2E2" height="15" width="125" x="170" y="165">
#                           </rect>
#                           <rect fill="#E2E2E2" height="15" width="135" x="170" y="185">
#                           </rect>
#                           <rect fill="#E2E2E2" height="15" width="140" x="170" y="205">
#                           </rect>
#                           <rect fill="#E2E2E2" height="15" width="140" x="325" y="145">
#                           </rect>
#                           <rect fill="#E2E2E2" height="15" width="125" x="325" y="165">
#                           </rect>
#                           <rect fill="#E2E2E2" height="15" width="135" x="325" y="185">
#                           </rect>
#                           <rect fill="#E2E2E2" height="15" width="140" x="325" y="205">
#                           </rect>
#                          </svg>
#                         </div>
#                         <div aria-label="Ver más" class="cxense-recommendations-iframe-show-more-btn" overflow="" role="button" tabindex="0">
#                          Ver más
#                         </div>
#                        </amp-iframe>
#                       </div>
#                       <div class="ad is-display-flex center" subscriptions-actions="" subscriptions-display="NOT granted">
#                        <!-- DUST PATH: /usr/src/app/node_modules/frontend-core/views/widgets/fc_adBanner_amp.dust/ -->
#                        <div class="ad-wrapper">
#                         <amp-ad data-slot="/349353471/p12_listado_300x600_MID" height="600" type="doubleclick" width="300">
#                         </amp-ad>
#                        </div>
#                       </div>
#                      </section>
#                     </article>
#                    </div>
#                   </article>
#                  </div>
#                  <footer class="footer">
#                   <div class="container">
#                    <!-- Footer -->
#                    <!-- DUST PATH: /usr/src/app/src/templates/partials/amp/footer_amp.dust/ -->
#                    <footer>
#                     <!-- Logos -->
#                     <div>
#                      <ul class="flex-container space-between">
#                       <li>
#                        <a href="https://www.pagina12.com.ar">
#                         <amp-img alt="Pagina12" class="footer-logo" height="40" layout="fixed-height" src="https://www.pagina12.com.ar/assets/media/assets/Pagina12-Logo-footer_blanco.svg?v=1.0.247">
#                         </amp-img>
#                        </a>
#                       </li>
#                       <li>
#                        <a href="http://octubre.com" target="_blank">
#                         <amp-img alt="Grupo Octubre" height="25" layout="fixed" src="https://www.pagina12.com.ar/assets/media/assets/Logo-octubre-color-footer.svg?v=1.0.247" width="102">
#                         </amp-img>
#                        </a>
#                       </li>
#                      </ul>
#                     </div>
#                     <div class="iconos flex-container">
#                      <!-- Social Media -->
#                      <div class="social-media">
#                       <ul>
#                        <li>
#                         <a href="https://www.facebook.com/Pagina12ok/" rel="me nofollow" target="_blank">
#                          <amp-img alt="Facebook" height="30" layout="fixed" src="https://www.pagina12.com.ar/assets/media/assets/social/facebook-white.svg?v=1.0.247" width="30">
#                          </amp-img>
#                         </a>
#                        </li>
#                        <li>
#                         <a href="https://twitter.com/pagina12" rel="me nofollow" target="_blank">
#                          <amp-img alt="Twitter" height="30" layout="fixed" src="https://www.pagina12.com.ar/assets/media/assets/social/twitter-white.svg?v=1.0.247" width="30">
#                          </amp-img>
#                         </a>
#                        </li>
#                        <li>
#                         <a href="https://www.instagram.com/pagina12/" rel="me nofollow" target="_blank">
#                          <amp-img alt="Instagram" height="30" layout="fixed" src="https://www.pagina12.com.ar/assets/media/assets/social/instagram-white.svg?v=1.0.247" width="30">
#                          </amp-img>
#                         </a>
#                        </li>
#                        <li>
#                         <a href="https://www.youtube.com/channel/UCJNDedOnljCssaiRZqg8-Dg" rel="me nofollow" target="_blank">
#                          <amp-img alt="Youtube" height="30" layout="fixed" src="https://www.pagina12.com.ar/assets/media/assets/social/youtube-white.svg?v=1.0.247" width="30">
#                          </amp-img>
#                         </a>
#                        </li>
#                        <li>
#                         <a href="https://t.me/pagina12" rel="me nofollow" target="_blank">
#                          <amp-img alt="Telegram" height="30" layout="fixed" src="https://www.pagina12.com.ar/assets/media/assets/social/telegram-white.svg?v=1.0.247" width="30">
#                          </amp-img>
#                         </a>
#                        </li>
#                       </ul>
#                      </div>
#                      <!-- RSS -->
#                      <div class="rss">
#                       <a class="rss" href="https://www.pagina12.com.ar/pagina/rss">
#                        <amp-img alt="RSS" height="22" layout="fixed" src="https://www.pagina12.com.ar/assets/media/assets/icon-rss.svg?v=1.0.247" width="22">
#                        </amp-img>
#                        <label>
#                         <strong>
#                          RSS
#                         </strong>
#                        </label>
#                       </a>
#                      </div>
#                      <!-- Contacto -->
#                      <div class="contacto">
#                       <a href="https://www.pagina12.com.ar/pagina/Contacto">
#                        <strong>
#                         Contacto
#                        </strong>
#                       </a>
#                      </div>
#                     </div>
#                     <!-- Otras publicaciones -->
#                     <div class="link-list">
#                      <h4>
#                       OTRAS PUBLICACIONES
#                      </h4>
#                      <div class="mini-hr">
#                      </div>
#                      <ul>
#                       <li>
#                        <a href="http://radioam750.com.ar">
#                         AM|750
#                        </a>
#                       </li>
#                       <li>
#                        <a href="https://oktubre.fm">
#                         Oktubre FM
#                        </a>
#                       </li>
#                       <li>
#                        <a href="http://carasycaretas.org.ar">
#                         Caras y Caretas
#                        </a>
#                       </li>
#                       <li>
#                        <a href="https://salas.carasycaretas.org.ar/">
#                         Caras y Caretas Sala
#                        </a>
#                       </li>
#                       <li>
#                        <a href="https://octubretv.com/">
#                         Octubre TV
#                        </a>
#                       </li>
#                       <li>
#                        <a href="http://www.editorialoctubre.com.ar">
#                         Editorial Octubre
#                        </a>
#                       </li>
#                       <li>
#                        <a href="http://www.diarioz.com.ar">
#                         Diario Z
#                        </a>
#                       </li>
#                       <li>
#                        <a href="http://elplanetaurbano.com">
#                         El Planeta Urbano
#                        </a>
#                       </li>
#                       <li>
#                        <a href="https://fmlike.com.ar/">
#                         FM Like
#                        </a>
#                       </li>
#                       <li>
#                        <a href="http://www.iso.edu.ar">
#                         ISO
#                        </a>
#                       </li>
#                       <li>
#                        <a href="http://umet.edu.ar">
#                         UMET
#                        </a>
#                       </li>
#                       <li>
#                        <a href="http://latinoamericapiensa.com">
#                         Latinoamérica Piensa
#                        </a>
#                       </li>
#                       <li>
#                        <a href="http://radiomalena.com">
#                         Malena FM
#                        </a>
#                       </li>
#                       <li>
#                        <a href="https://www.elnueve.com.ar/">
#                         El Nueve
#                        </a>
#                       </li>
#                       <li>
#                        <a href="https://cluboctubre947.com/">
#                         Club 947
#                        </a>
#                       </li>
#                       <li>
#                        <a href="https://fmaspen.com/">
#                         Aspen 102.3
#                        </a>
#                       </li>
#                      </ul>
#                     </div>
#                     <!-- Featured Tags -->
#                     <div class="featured-tags">
#                      <h4>
#                       TAGS MÁS IMPORTANTES
#                      </h4>
#                      <div class="mini-hr">
#                      </div>
#                      <ul>
#                       <li>
#                        <a href="https://www.pagina12.com.ar/tags/615-axel-kicillof">
#                         Axel Kicillof
#                        </a>
#                       </li>
#                       <li>
#                        <a href="https://www.pagina12.com.ar/tags/6850-clases">
#                         clases
#                        </a>
#                       </li>
#                       <li>
#                        <a href="https://www.pagina12.com.ar/tags/983-neoliberalismo">
#                         Neoliberalismo
#                        </a>
#                       </li>
#                       <li>
#                        <a href="https://www.pagina12.com.ar/tags/943-dolar">
#                         Dólar
#                        </a>
#                       </li>
#                       <li>
#                        <a href="https://www.pagina12.com.ar/tags/8224-che-guevara">
#                         Che Guevara
#                        </a>
#                       </li>
#                       <li>
#                        <a href="https://www.pagina12.com.ar/tags/20851-jair-bolsonaro">
#                         Jair Bolsonaro
#                        </a>
#                       </li>
#                       <li>
#                        <a href="https://www.pagina12.com.ar/tags/48144-jorge-gonzalez-nieva">
#                         Jorge González Nieva
#                        </a>
#                       </li>
#                      </ul>
#                     </div>
#                     <!-- Disclamer -->
#                     <p class="disclaimer">
#                      <span>
#                       República Argentina
#                      </span>
#                      <span>
#                       |
#                      </span>
#                      <span>
#                       Todos los derechos reservados
#                      </span>
#                      <span>
#                       |
#                      </span>
#                      <a href="https://www.pagina12.com.ar/pagina/politica-de-privacidad">
#                       Política de privacidad
#                      </a>
#                      <span>
#                       |
#                      </span>
#                      <a href="https://www.pagina12.com.ar/pagina/terminos-y-condiciones">
#                       Términos y Condiciones
#                      </a>
#                      <span>
#                       © 2000-2020 www.pagina12.com.ar
#                      </span>
#                     </p>
#                    </footer>
#                   </div>
#                  </footer>
#                 </article>
#                </div>
#               </article>
#              </div>
#             </article>
#            </div>
#           </article>
#          </div>
#         </article>
#        </div>
#       </article>
#      </div>
#     </section>
#    </div>
#   </div>
#  </body>
# </html>

# %%
featured_article = s_seccion.find('div', attrs={'class':'article-item__content'})
featured_article
# Out:
# <div class="article-item__content"><!-- Title --><h2 class="title-list"><a href="https://www.pagina12.com.ar/298006-la-ley-de-gondolas-ya-rige-en-provincia">La ley de gondolas ya rige en Provincia</a></h2><!-- Kicker --><p><a href="https://www.pagina12.com.ar/298006-la-ley-de-gondolas-ya-rige-en-provincia">El senado bonaerense aprobó la adhesión a la iniciativa nacional</a></p></div>

# %%
featured_article.a.get('href')
# Out:
# 'https://www.pagina12.com.ar/298006-la-ley-de-gondolas-ya-rige-en-provincia'

# %%
article_list = s_seccion.find('section',attrs={'class':'list-content'}).find_all('h4', attrs={'class':'is-display-inline'})
article_list
# Out:
# [<h4 class="is-display-inline title-list"><a class="" href="https://www.pagina12.com.ar/298059-banco-mundial-la-economia-argentina-caera-12-3-por-ciento-es">Banco Mundial: la economía argentina caerá 12,3 por ciento este año</a></h4>,
#  <h4 class="is-display-inline title-list"><a class="" href="https://www.pagina12.com.ar/298084-round-de-conocimiento-y-autocritica">Round de conocimiento y autocrítica</a></h4>,
#  <h4 class="is-display-inline title-list"><a class="" href="https://www.pagina12.com.ar/298096-crece-la-liquidacion-de-exportaciones">Crece la liquidación de exportaciones</a></h4>,
#  <h4 class="is-display-inline title-list"><a class="" href="https://www.pagina12.com.ar/298132-a-la-mesa-le-falta-una-pata">A la Mesa le falta una pata</a></h4>,
#  <h4 class="is-display-inline title-list"><a class="" href="https://www.pagina12.com.ar/298136-el-dolar-paralelo-mete-presion-167-pesos">El dólar paralelo mete presión: 167 pesos</a></h4>,
#  <h4 class="is-display-inline title-list"><a class="" href="https://www.pagina12.com.ar/298140-las-expectativas-de-la-economia-real-se-moderan">Las expectativas de la economía real se moderan</a></h4>,
#  <h4 class="is-display-inline title-list"><a class="" href="https://www.pagina12.com.ar/298150-como-frenar-la-devaluacion">Cómo frenar la devaluación </a></h4>,
#  <h4 class="is-display-inline title-list"><a class="" href="https://www.pagina12.com.ar/295282-jubilados-octubre-2020-el-cronograma-de-pago-completo-de-la-">Jubilados octubre 2020: el cronograma de pago completo de la Anses</a></h4>]

# %%
#article_below = article_list[0]
article_links = [article_below1.a.get('href') for article_below1 in article_list]
article_links
# Out:
# ['https://www.pagina12.com.ar/298059-banco-mundial-la-economia-argentina-caera-12-3-por-ciento-es',
#  'https://www.pagina12.com.ar/298084-round-de-conocimiento-y-autocritica',
#  'https://www.pagina12.com.ar/298096-crece-la-liquidacion-de-exportaciones',
#  'https://www.pagina12.com.ar/298132-a-la-mesa-le-falta-una-pata',
#  'https://www.pagina12.com.ar/298136-el-dolar-paralelo-mete-presion-167-pesos',
#  'https://www.pagina12.com.ar/298140-las-expectativas-de-la-economia-real-se-moderan',
#  'https://www.pagina12.com.ar/298150-como-frenar-la-devaluacion',
#  'https://www.pagina12.com.ar/295282-jubilados-octubre-2020-el-cronograma-de-pago-completo-de-la-']

# %%
def obtener_notas(soup):
    '''Función que recibe un objeto de Beautiful Soup de una página de una sección y devuelve una lista de URLS 
    a la notas de esa seccion'''
    
    lista_notas = []
    
    #Obtengo el artículo promocionado
    featured_article = soup.find('div', attrs={'class':'article-item__content'})
    if featured_article:
        lista_notas.append(featured_article.a.get('href'))
        
    #Obtengo el listado de artículos
    article_list = s_seccion.find('section',attrs={'class':'list-content'}).find_all('h4', attrs={'class':'is-display-inline'})
    for i in article_list:
        lista_notas.append(i.a.get('href'))
    
    return lista_notas

# %%
lista_notas = (obtener_notas(s_seccion))
lista_notas
# Out:
# ['https://www.pagina12.com.ar/298006-la-ley-de-gondolas-ya-rige-en-provincia',
#  'https://www.pagina12.com.ar/298059-banco-mundial-la-economia-argentina-caera-12-3-por-ciento-es',
#  'https://www.pagina12.com.ar/298084-round-de-conocimiento-y-autocritica',
#  'https://www.pagina12.com.ar/298096-crece-la-liquidacion-de-exportaciones',
#  'https://www.pagina12.com.ar/298132-a-la-mesa-le-falta-una-pata',
#  'https://www.pagina12.com.ar/298136-el-dolar-paralelo-mete-presion-167-pesos',
#  'https://www.pagina12.com.ar/298140-las-expectativas-de-la-economia-real-se-moderan',
#  'https://www.pagina12.com.ar/298150-como-frenar-la-devaluacion',
#  'https://www.pagina12.com.ar/295282-jubilados-octubre-2020-el-cronograma-de-pago-completo-de-la-']

# %%
url_nota = lista_notas[7]
url_nota
# Out:
# 'https://www.pagina12.com.ar/298150-como-frenar-la-devaluacion'

# %%
for link in lista_notas:
    try:
        nota = requests.get(link)
        if nota.status_code == 200:
            s_nota = BeautifulSoup(nota.text,'lxml')
            #Extrae titulo
            titulo = s_nota.find('h1',attrs={'class':'article-title'})
            fecha = s_nota.find('span',attrs={'pubdate':'pubdate'}).get('datetime')
            autor = s_nota.find('div',attrs={'class':'article-author'}).find('a').text
            descripcion = s_nota.find('h2',attrs={'class':'article-prefix'}).text
            resumen = s_nota.find('div',attrs={'class':'article-summary'}).text
            cuerpo = s_nota.find('div',attrs={'class':'article-text'}).text
            print(titulo.text)
            print(fecha)
            if autor == None:
                print('Articulo sin autor')
            else:
                print('Autor: ' + autor)
            print(descripcion)
            print(resumen)
            print(cuerpo)
            print('----------')
    except Exception as e:
        print("Error:")
        print(e)
        print('\n')
# Out:
# La ley de gondolas ya rige en Provincia
# 2020-10-10
# Autor: Natalí Risso
# El senado bonaerense aprobó la adhesión a la iniciativa nacional
# La iniciativa establece pautas para que los supermercados exhiban y ofrezcan de forma clara los productos y limita los espacios de comercialización de las grandes marcas en favor de pequeños y medianos productores.
# El senado bonaerense aprobó la adhesión a la Ley de Góndolas para favorecer a productores regionales. El proyecto, que obtuvo su aprobación la semana anterior en Diputados, establece pautas para que los supermercados exhiban y ofrezcan de forma clara los productos y limita los espacios de comercialización de las grandes marcas en favor de pequeños y medianos productores. "De este modo, las micro y pequeñas empresas de la provincia de Buenos Aires tendrán un lugar en las grandes cadenas de supermercados y podrán ampliar su espacio de comercialización" informó el cuerpo que preside Verónica Magario.Tal como sucedió a nivel nacional, y la semana anterior en la cámara de diputados provincial, el proyecto fue apoyado por bloques oficialistas y opositores en unanimidad. Según los legisladores, el cambio favorecerá tanto a las empresas pequeñas y medianas de cada región de la provincia, que ahora tendrán asegurado un canal de comercialización; como también a los consumidores, que podrán disponer de una oferta de mayor variedad de productos.En supermercados bonaerensesLa ley adhiere a la ley Nacional 27.545, que obtuvo su sanción en febrero de este año y aún se encuentra pendiente de reglamentación, pero cuenta con dos especificidades para el territorio bonaerense.En primer lugar, profundiza uno de los requisitos de la ley nacional, que establece que los productos de micro y pequeñas empresas deben estar destacados en las góndolas y locaciones virtuales con un isologotipo que diseñe la autoridad de aplicación que exprese la le
an instalar que las reservas se agotan a mitad de noviembre. La verdad es que todas las medidas del Banco Central y del Ministerio de Economía se hicieron con reservas para poder responder a las presiones y evitar una devaluación. No hay ninguna necesidad de devaluar. Los que presionan por la devaluación quieren provocar una desestabilización política”, dicen en el gobierno.Las limitaciones a la compra de dólares, afirman, bajaron la demanda de 400 millones a 100 millones por parte del público minorista en los primeros días de octubre respecto del mismo lapso en septiembre. La liquidación de exportaciones, agregan, empezó a acelerarse y será más evidente la próxima semana, lo que empezará a disminuir la presión sobre las reservas.  ...
# La posibilidad de un desdoblamiento del mercado cambiario, en tanto, es rechazada por funcionarios y economistas cercanos al oficialismo. Coindicen en que es la antesala para una devaluación, que se seguirá buscando evitar.
# ----------
# Error:
# 'NoneType' object has no attribute 'text'

# %%
try:
        nota = requests.get(link)
        if nota.status_code == 200:
            s_nota = BeautifulSoup(nota.text,'lxml')
            #Extrae titulo
            try:
                titulo = s_nota.find('h1',attrs={'class':'article-title'})
                print(titulo.text)
            except Exception as e:
                pass
            fecha = s_nota.find('span',attrs={'pubdate':'pubdate'}).get('datetime')
            print(fecha)
            try:
                autor = s_nota.find('div',attrs={'class':'article-author'}).find('a').text
                if autor == None:
                    print('Articulo sin autor')
                else:
                    print('Autor: ' + autor)
            except Exception as e:
                pass
            try:
                descripcion = s_nota.find('h2',attrs={'class':'article-prefix'}).text
                print(descripcion)
            except Exception as e:
                print(e)
            try:
                resumen = s_nota.find('div',attrs={'class':'article-summary'}).text
                if resumen == None:
                    print('Articulo sin resumen')
                else:
                    print(resumen)
            except Exception as e:
                print('Articulo sin resumen')
            cuerpo = s_nota.find('div',attrs={'class':'article-text'}).text
            print(cuerpo)
            print('--------------------------')
except Exception as e:
        print("Error:")
        print(e)
        print('\n')
# Out:
# Jubilados octubre 2020: el cronograma de pago completo de la Anses
# 2020-10-09
# Autor: Isabella Cosse
# Quiénes cobran este viernes 9
# Articulo sin resumen
# Los jubilados y pensionados con DNI finalizado en 1 cobran este viernes 9 de octubre. De acuerdo al cronograma de cobro que armó la Anses, durante este mes el pago a los beneficiarios se realiza según la finalización de su número de Documento Nacional de Identidad. El cronograma de pagoFechas de cobro de jubilados y pensionados con haberes inferiores a $20.354DNI terminados en 0: jueves 8 de octubreDNI terminados en 1: viernes 9 de octubreDNI terminados en 2: martes 13 de octubreDNI terminados en 3: miércoles 14 de octubreDNI terminados en 4: jueves 15 de octubreDNI terminados en 5: viernes 16 de octubreDNI terminados en 6: lunes 19 de octubreDNI terminados en 7: martes 20 de octubre DNI terminados en 8: miércoles 21 de octubreDNI terminados en 9: jueves 22 de octubre
#
#
#
#
# Fechas de cobro de jubilados y pensionados con haberes superiores a $20.374DNI terminados en 0 y 1: viernes 23 de octubreDNI terminados en 2 y 3: lunes 26 de octubreDNI terminados en 4 y 5: martes 27 de octubreDNI terminados en 6 y 7: miércoles 28 de octubreDNI terminados en 8 y 9: jueves 29 de octubre
#
#
#
#
# Dónde y cómo cobrarEl haber de este mes se pagará en las sucursales bancarias habilitadas, que atenderán únicamente por ventanilla y sin turno previo a los beneficiarios.Los jubilados y pensionados deben acercarse a las entidades solo en las fechas asignadas y sus haberes permanecerán en sus cuentas.La ANSES recordó que el trámite de Supervivencia/Fe de Vida para los jubilados y pensionados se encuentra suspendido. Esto significa que no es necesario que los adultos mayores concurran a los bancos para llevarlo a cabo.Los calendarios de pagos de otras prestaciones· Asignación Universal por Hijo· Asignación por Embarazo Los cronogramas de cobro de todas las prestaciones que paga la Anses pueden consultarse a través de su página web, redes sociales o llamando al 130.
# --------------------------

# %%
media = s_nota.find('div',attrs={'article-main-media-image'})

# %%
imagenes = media.find_all('img')
imagenes
# Out:
# [<img alt="Los jubilados y pensionados cobran según el número de finalización del DNI de acuerdo al cronograma de pagos que armó la Anses." class="lazyload show-for-xsmall-only" data-src="https://images.pagina12.com.ar/styles/focal_3_2_470x313/public/2020-10/108620-jub_0.jpg?itok=1_IVpbn4" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif"/>,
#  <img alt="Los jubilados y pensionados cobran según el número de finalización del DNI de acuerdo al cronograma de pagos que armó la Anses." class="lazyload show-for-small-only" data-src="https://images.pagina12.com.ar/styles/focal_3_2_960x640/public/2020-10/108620-jub_0.jpg?itok=WWXbiOP9" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif"/>,
#  <img alt="Los jubilados y pensionados cobran según el número de finalización del DNI de acuerdo al cronograma de pagos que armó la Anses." class="lazyload show-for-medium-only" data-src="https://images.pagina12.com.ar/styles/focal_3_2_960x640/public/2020-10/108620-jub_0.jpg?itok=WWXbiOP9" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif"/>,
#  <img alt="Los jubilados y pensionados cobran según el número de finalización del DNI de acuerdo al cronograma de pagos que armó la Anses." class="lazyload show-for-large-only" data-src="https://images.pagina12.com.ar/styles/focal_3_2_960x640/public/2020-10/108620-jub_0.jpg?itok=WWXbiOP9" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif"/>,
#  <img alt="Los jubilados y pensionados cobran según el número de finalización del DNI de acuerdo al cronograma de pagos que armó la Anses." class="lazyload show-for-xlarge" data-src="https://images.pagina12.com.ar/styles/focal_3_2_960x640/public/2020-10/108620-jub_0.jpg?itok=WWXbiOP9" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif"/>]

# %%
if len(imagenes)==0:
    print('no se encontraron imagenes')
else:
    imagen = imagenes[-1]
    img_src = imagen.get('data-src')
    print(img_src)
# Out:
# https://images.pagina12.com.ar/styles/focal_3_2_960x640/public/2020-10/108620-jub_0.jpg?itok=WWXbiOP9

# %%
img_req = requests.get(img_src)

# %%
img_req.status_code
# Out:
# 200

# %%
from IPython.display import Image

# %%
Image(img_req.content)

# %% [markdown]
# # Iniciando Scraper

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.pagina12.com.ar/'
p12 = requests.get(url)

# %%
s = BeautifulSoup(p12.text, 'lxml')

# %%
secciones = s.find('div', attrs={'class':'p12-dropdown-column'}).find_all('a')
secciones

# %%
links_secciones = [seccion.get('href') for seccion in secciones]
links_secciones

# %% [markdown]
# ## Función para obtener la lista de urls de una sección de noticias

# %%
def obtener_notas(soup):
    '''Función que recibe un objeto de Beautiful Soup de una página de una sección y devuelve una lista de URLS 
    a la notas de esa seccion'''
    
    lista_notas = []
    
    #Obtengo el artículo promocionado
    featured_article = soup.find('div', attrs={'class':'article-item__content'})
    if featured_article:
        lista_notas.append(featured_article.a.get('href'))
        
    #Obtengo el listado de artículos
    article_list = s_seccion.find('section',attrs={'class':'list-content'}).find_all('h4', attrs={'class':'is-display-inline'})
    for i in article_list:
        lista_notas.append(i.a.get('href'))
    
    return lista_notas

# %% [markdown]
# ## Función para obtener los datos de cada noticia

# %%
def request_links(s_nota):
    #Diccionario vacío para poblar data
    rect_dict = {}
    
    #Extraemos fecha 
    fecha = s_nota.find('span',attrs={'pubdate':'pubdate'})
    if fecha:
        rect_dict['fecha'] = fecha.get('datetime')
    else:
        rect_dict['fecha'] = None 
    
    #Extraemos el título
    titulo = s_nota.find('h1',attrs={'class':'article-title'})
    if titulo:
        rect_dict['titulo'] = titulo.text
    else:
        rect_dict['titulo'] = None
        
    #Extraemos el autor 
    autor = s_nota.find('div',attrs={'class':'article-author'}).find('a')
    if autor:
        rect_dict['autor'] = autor.text
    else:
        rect_dict['autor'] = None
        
    #Extraemos la descripción
    descripcion = s_nota.find('h2',attrs={'class':'article-prefix'})
    if descripcion:
        rect_dict['descripcion'] = descripcion.text
    else:
        rect_dict['descripcion'] = None
    
    #Extraemos el resumen
    resumen = s_nota.find('div',attrs={'class':'article-summary'})
    if resumen:
            rect_dict['resumen'] = resumen.text
    else:
        rect_dict['resumen'] = None
    
    #Obtenemos la imagen
    media = s_nota.find('div',attrs={'article-main-media-image'})
    if media:
        imagenes = media.find_all('img')
        if len(imagenes)==0:
            print('no se encontraron imagenes')
        else:
            imagen = imagenes[-1]
            img_src = imagen.get('data-src')
            try:
                img_req = requests.get(img_src)
                if img_req.status_code == 200:
                    rect_dict['img'] = img_req.contentt
                else:
                    rect_dict['img'] = None
            except Exception as e:
                print('No se pudo obtener la imagen')
    else:
        print('No se encontró media')
    
    #Extraemos el cuerpo
    cuerpo = s_nota.find('div',attrs={'class':'article-text'})
    if descripcion:
        rect_dict['cuerpo'] = cuerpo.text
    else:
        rect_dict['cuerpo'] = None
    
    return rect_dict

# %% [markdown]
# ## Función para iniciar el scraping a la url

# %%
def scrape_nota(url):
    try: 
        nota = requests.get(url)
    except Exception as e:
        print('Error scrapeando la URL', url)
        print(e)
        return None
    
    if nota.status_code != 200:
        print(f'Error obteniendo nota {url}')
        print(f'Status code = {nota.status_code}')
        return None 
              
    s_nota = BeautifulSoup(nota.text, 'lxml')
              
    rect_dict = request_links(s_nota)
    rect_dict['url'] = url 
              
    return rect_dict

# %%
scrape_nota(url_nota)
# Out:
# No se pudo obtener la imagen
# {'fecha': '2020-10-10',
#  'titulo': 'Cómo frenar la devaluación\xa0',
#  'autor': 'David Cufré',
#  'descripcion': 'Se agudizan las presiones cambiarias',
#  'resumen': 'El gabinete económico atribuye la suba de los dólares financieros a maniobras especulativas de fondos de inversión y a un intento de desestabilización política. Confía en que podrá neutralizarlas con las medidas que ya se tomaron y otras que seguirán en los próximos días.',
#  'cuerpo': 'El valor del dólar ilegal alcanzó este viernes el mismo nivel, traído al presente, que tenía el dólar oficial en mayo de 1989, en medio del proceso de hiperinflación alfonsinista. Es decir, los 167 pesos actuales del mercado paralelo están en un rango de equivalencia con la moneda más depreciada que tuvo el país en 31 años. En 1981, en la etapa de la dictadura de Roberto Viola como presidente, la devaluación del ministro de Economía, Lorenzo Sigaut, llevó el dólar a un escalón que en este momento serían 147 pesos. El dólar de abril de 2002, para completar la comparación con los momentos más críticos de la economía nacional, hoy serían 123 pesos, según los cálculos de la consultora Synthesis, que dirige el ex presidente
#  'https://www.pagina12.com.ar/secciones/cultura',
#  'https://www.pagina12.com.ar/secciones/plastica',
#  'https://www.pagina12.com.ar/secciones/psicologia',
#  'https://www.pagina12.com.ar/secciones/hoy',
#  'https://www.pagina12.com.ar/secciones/cartas-de-lectores',
#  'https://www.pagina12.com.ar/secciones/contratapa',
#  'https://www.pagina12.com.ar/secciones/audiovisuales',
#  'https://www.pagina12.com.ar/secciones/recordatorios',
#  'https://www.pagina12.com.ar/secciones/consumo',
#  'https://www.pagina12.com.ar/secciones/salta12',
#  'https://www.pagina12.com.ar/secciones/podcasts',
#  'https://www.pagina12.com.ar/secciones/soci@s',
#  'https://www.pagina12.com.ar/secciones/la-ventana']

# %% [markdown]
# ## Obtener todos los links a scrapear

# %%
notas = []
for link in links_secciones:
    try:
        r = requests.get(link)
        if r.status_code == 200:
            soup = BeautifulSoup(r.text,'lxml')
            notas.extend(obtener_notas(soup))
        else:
            print('No se pudo obtener la seccion', link)
    except:
        print('No se pudo obtener el link ', link)

# %%
notas
# Out:
# ['https://www.pagina12.com.ar/298357-que-debe-hacer-alberto-fernandez-para-ganar-la-proximas-elec',
#  'https://www.pagina12.com.ar/298059-banco-mundial-la-economia-argentina-caera-12-3-por-ciento-es',
#  'https://www.pagina12.com.ar/298084-round-de-conocimiento-y-autocritica',
#  'https://www.pagina12.com.ar/298096-crece-la-liquidacion-de-exportaciones',
#  'https://www.pagina12.com.ar/298132-a-la-mesa-le-falta-una-pata',
#  'https://www.pagina12.com.ar/298136-el-dolar-paralelo-mete-presion-167-pesos',
#  'https://www.pagina12.com.ar/298140-las-expectativas-de-la-economia-real-se-moderan',
#  'https://www.pagina12.com.ar/298150-como-frenar-la-devaluacion',
#  'https://www.pagina12.com.ar/295282-jubilados-octubre-2020-el-cronograma-de-pago-completo-de-la-',
#  'https://www.pagina12.com.ar/298328-el-dolar-en-el-campo-de-batalla',
#  'https://www.pagina12.com.ar/298059-banco-mundial-la-economia-argentina-caera-12-3-por-ciento-es',
#  'https://www.pagina12.com.ar/298084-round-de-conocimiento-y-autocritica',
#  'https://www.pagina12.com.ar/298096-crece-la-liquidacion-de-exportaciones',
#  'https://www.pagina12.com.ar/298132-a-la-mesa-le-falta-una-pata',
#  'https://www.pagina12.com.ar/298136-el-dolar-paralelo-mete-presion-167-pesos',
#  'https://www.pagina12.com.ar/298140-las-expectativas-de-la-economia-real-se-moderan',
#  'https://www.pagina12.com.ar/298150-como-frenar-la-devaluacion',
#  'https://www.pagina12.com.ar/295282-jubilados-octubre-2020-el-cronograma-de-pago-completo-de-la-',
#  'https://www.pagina12.com.ar/298356-dia-internacional-de-la-nina',
#  'https://www.pagina12.com.ar/298059-banco-mundial-la-economia-argentina-caera-12-3-por-ciento-es',
#  'https://www.pagina12.com.ar/298084-round-de-conocimiento-y-autocritica',
#  'https://www.pagina12.com.ar/298096-crece-la-liquidacion-de-exportaciones',
#  'https://www.pagina12.com.ar/298132-a-la-mesa-le-falta-una-pata',
#  'https://www.pagina12.com.ar/298136-el-dolar-paralelo-mete-presion-167-pesos',
#  'https://www.pagina12.com.ar/298140-las-expectativas-de-la-economia-real-se-moderan',
#  'https://www.pagina12.com.ar/298150-como-frenar-la-devaluacion',
#  'https://www.pagina12.com.ar/295282-jubilados-octubre-2020-el-cronograma-de-pago-completo-de-la-',
#  'https://www.pagina12.com.ar/298059-banco-mundial-la-economia-argentina-caera-12-3-por-ciento-es',
#  'https://www.pagina12.com.ar/298084-round-de-conocimiento-y-autocritica',
#  'https://www.pagina12.com.ar/298096-crece-la-liquidacion-de-exportaciones',
#  'https://www.pagina12.com.ar/298132-a-la-mesa-le-falta-una-pata',
#  'https://www.pagina12.com.ar/298136-el-dolar-paralelo-mete-presion-167-pesos',
#  'https://www.pagina12.com.ar/298140-las-expectativas-de-la-economia-real-se-moderan',
#  'https://www.pagina12.com.ar/298150-como-frenar-la-devaluacion',
#  'https://www.pagina12.com.ar/295282-jubilados-octubre-2020-el-cronograma-de-pago-completo-de-la-',
#  'https://www.pagina12.com.ar/298344-la-conmebol-publico-los-audios-del-var-en-el-polemico-urugua',
#  'https://www.pagina12.com.ar/298059-banco-mundial-la-economia-argentina-caera-12-3-por-ciento-es',
#  'https://www.pagina12.com.ar/298084-round-de-conocimiento-y-autocritica',
#  'https://www.pagina12.com.ar/298096-crece-la-liquidacion-de-exportaciones',
#  'https://www.pagina12.com.ar/298132-a-la-mesa-le-falta-una-pata',
#  'https://www.pagina12.com.ar/298136-el-dolar-paralelo-mete-presion-167-pesos',
#  'https://www.pagina12.com.ar/298140-las-expectativas-de-la-economia-real-se-moderan',
#  'https://www.pagina12.com.ar/298150-como-frenar-la-devaluacion',
#  'https://www.pagina12.com.ar/295282-jubilados-octubre-2020-el-cronograma-de-pago-completo-de-la-',
#  'https://www.pagina12.com.ar/298299-encuentran-el-limite-maximo-de-la-velocidad-del-sonido',
#  'https://www.pagina12.com.ar/298059-banco-mundial-la-economia-argentina-caera-12-3-por-ciento-es',
#  'https://www.pagina12.com.ar/298084-round-de-conocimiento-y-autocritica',
#  'https://www.pagina12.com.ar/298096-crece-la-liquidacion-de-exportaciones',
#  'https://www.pagina12.com.ar/298132-a-la-mesa-le-falta-una-pata',
#  'https://www.pagina12.com.ar/298136-el-dolar-paralelo-mete-presion-167-pesos',
#  'https://www.pagina12.com.ar/298140-las-expectativas-de-la-economia-real-se-moderan',
#  'https://www.pagina12.com.ar/298150-como-frenar-la-devaluacion',
#  'https://www.pagina12.com.ar/295282-jubilados-octubre-2020-el-cronograma-de-pago-completo-de-la-',
#  'https://www.pagina12.com.ar/296798-plan-condor-2-0',
#  'https://www.pagina12.com.ar/298059-banco-mundial-la-economia-argentina-caera-12-3-por-ciento-es',
#  'https://www.pagina12.com.ar/298084-round-de-conocimiento-y-autocritica',
#  'https://www.pagina12.com.ar/298096-crece-la-liquidacion-de-exportaciones',
#  'https://www.pagina12.com.ar/298132-a-la-mesa-le-falta-una-pata',
#  'https://www.pagina12.com.ar/298136-el-dolar-paralelo-mete-presion-167-pesos',
#  'https://www.pagina12.com.ar/298140-las-expectativas-de-la-economia-real-se-moderan',
#  'https://www.pagina12.com.ar/298150-como-frenar-la-devaluacion',
#  'https://www.pagina12.com.ar/295282-jubilados-octubre-2020-el-cronograma-de-pago-completo-de-la-',
#  'https://www.pagina12.com.ar/298355-trump-vuelve-a-los-eventos-sin-dar-evidencias-de-estar-curad',
#  'https://www.pagina12.com.ar/298059-banco-mundial-la-economia-argentina-caera-12-3-por-ciento-es',
#  'https://www.pagina12.com.ar/298084-round-de-conocimiento-y-autocritica',
#  'https://www.pagina12.com.ar/298096-crece-la-liquidacion-de-exportaciones',
#  'https://www.pagina12.com.ar/298132-a-la-mesa-le-falta-una-pata',
#  'https://www.pagina12.com.ar/298136-el-dolar-paralelo-mete-presion-167-pesos',
#  'https://www.pagina12.com.ar/298140-las-expectativas-de-la-economia-real-se-moderan',
#  'https://www.pagina12.com.ar/298150-como-frenar-la-devaluacion',
#  'https://www.pagina12.com.ar/295282-jubilados-octubre-2020-el-cronograma-de-pago-completo-de-la-',
#  'https://www.pagina12.com.ar/298059-banco-mundial-la-economia-argentina-caera-12-3-por-ciento-es',
#  'https://www.pagina12.com.ar/298084-round-de-conocimiento-y-autocritica',
#  'https://www.pagina12.com.ar/298096-crece-la-liquidacion-de-exportaciones',
#  'https://www.pagina12.com.ar/298132-a-la-mesa-le-falta-una-pata',
#  'https://www.pagina12.com.ar/298136-el-dolar-paralelo-mete-presion-167-pesos',
#  'https://www.pagina12.com.ar/298140-las-expectativas-de-la-economia-real-se-moderan',
#  'https://www.pagina12.com.ar/298150-como-frenar-la-devaluacion',
#  'https://www.pagina12.com.ar/295282-jubilados-octubre-2020-el-cronograma-de-pago-completo-de-la-',
#  'https://www.pagina12.com.ar/297649-sin-oferta-para-los-docentes-universitarios',
#  'https://www.pagina12.com.ar/298059-banco-mundial-la-economia-argentina-caera-12-3-por-ciento-es',
#  'https://www.pagina12.com.ar/298084-round-de-conocimiento-y-autocritica',
#  'https://www.pagina12.com.ar/298096-crece-la-liquidacion-de-exportaciones',
#  'https://www.pagina12.com.ar/298132-a-la-mesa-le-falta-una-pata',
#  'https://www.pagina12.com.ar/298136-el-dolar-paralelo-mete-presion-167-pesos',
#  'https://www.pagina12.com.ar/298140-las-expectativas-de-la-economia-real-se-moderan',
#  'https://www.pagina12.com.ar/298150-como-frenar-la-devaluacion',
#  'https://www.pagina12.com.ar/295282-jubilados-octubre-2020-el-cronograma-de-pago-completo-de-la-',
#  'https://www.pagina12.com.ar/275696-ajedrez-un-campeon-que-se-dejo-ganar-para-hacer-justicia',
#  'https://www.pagina12.com.ar/298059-banco-mundial-la-economia-argentina-caera-12-3-por-ciento-es',
#  'https://www.pagina12.com.ar/298084-round-de-conocimiento-y-autocritica',
#  'https://www.pagina12.com.ar/298096-crece-la-liquidacion-de-exportaciones',
#  'https://www.pagina12.com.ar/298132-a-la-mesa-le-falta-una-pata',
#  'https://www.pagina12.com.ar/298136-el-dolar-paralelo-mete-presion-167-pesos',
#  'https://www.pagina12.com.ar/298140-las-expectativas-de-la-economia-real-se-moderan',
#  'https://www.pagina12.com.ar/298150-como-frenar-la-devaluacion',
#  'https://www.pagina12.com.ar/295282-jubilados-octubre-2020-el-cronograma-de-pago-completo-de-la-',
#  'https://www.pagina12.com.ar/297851-murio-gabo-ferro',
#  'https://www.pagina12.com.ar/298059-banco-mundial-la-economia-argentina-caera-12-3-por-ciento-es',
#  'https://www.pagina12.com.ar/298084-round-de-conocimiento-y-autocritica',
#  'https://www.pagina12.com.ar/298096-crece-la-liquidacion-de-exportaciones',
#  'https://www.pagina12.com.ar/298132-a-la-mesa-le-falta-una-pata',
#  'https://www.pagina12.com.ar/298136-el-dolar-paralelo-mete-presion-167-pesos',
#  'https://www.pagina12.com.ar/298140-las-expectativas-de-la-economia-real-se-moderan',
#  'https://www.pagina12.com.ar/298150-como-frenar-la-devaluacion',
#  'https://www.pagina12.com.ar/295282-jubilados-octubre-2020-el-cronograma-de-pago-completo-de-la-',
#  'https://www.pagina12.com.ar/296959-secuencias-fotograficas-de-franjas-topograficas',
#  'https://www.pagina12.com.ar/298059-banco-mundial-la-economia-argentina-caera-12-3-por-ciento-es',
#  'https://www.pagina12.com.ar/298084-round-de-conocimiento-y-autocritica',
#  'https://www.pagina12.com.ar/298096-crece-la-liquidacion-de-exportaciones',
#  'https://www.pagina12.com.ar/298132-a-la-mesa-le-falta-una-pata',
#  'https://www.pagina12.com.ar/298136-el-dolar-paralelo-mete-presion-167-pesos',
#  'https://www.pagina12.com.ar/298140-las-expectativas-de-la-economia-real-se-moderan',
#  'https://www.pagina12.com.ar/298150-como-frenar-la-devaluacion',
#  'https://www.pagina12.com.ar/295282-jubilados-octubre-2020-el-cronograma-de-pago-completo-de-la-',
#  'https://www.pagina12.com.ar/297612-coronavirus-reconocer-un-cuerpo-no-es-una-despedida',
#  'https://www.pagina12.com.ar/298059-banco-mundial-la-economia-argentina-caera-12-3-por-ciento-es',
#  'https://www.pagina12.com.ar/298084-round-de-conocimiento-y-autocritica',
#  'https://www.pagina12.com.ar/298096-crece-la-liquidacion-de-exportaciones',
#  'https://www.pagina12.com.ar/298132-a-la-mesa-le-falta-una-pata',
#  'https://www.pagina12.com.ar/298136-el-dolar-paralelo-mete-presion-167-pesos',
#  'https://www.pagina12.com.ar/298140-las-expectativas-de-la-economia-real-se-moderan',
#  'https://www.pagina12.com.ar/298150-como-frenar-la-devaluacion',
#  'https://www.pagina12.com.ar/295282-jubilados-octubre-2020-el-cronograma-de-pago-completo-de-la-',
#  'https://www.pagina12.com.ar/298059-banco-mundial-la-economia-argentina-caera-12-3-por-ciento-es',
#  'https://www.pagina12.com.ar/298084-round-de-conocimiento-y-autocritica',
#  'https://www.pagina12.com.ar/298096-crece-la-liquidacion-de-exportaciones',
#  'https://www.pagina12.com.ar/298132-a-la-mesa-le-falta-una-pata',
#  'https://www.pagina12.com.ar/298136-el-dolar-paralelo-mete-presion-167-pesos',
#  'https://www.pagina12.com.ar/298140-las-expectativas-de-la-economia-real-se-moderan',
#  'https://www.pagina12.com.ar/298150-como-frenar-la-devaluacion',
#  'https://www.pagina12.com.ar/295282-jubilados-octubre-2020-el-cronograma-de-pago-completo-de-la-',
#  'https://www.pagina12.com.ar/109397-hombre-de-papel-durmiendo',
#  'https://www.pagina12.com.ar/298059-banco-mundial-la-economia-argentina-caera-12-3-por-ciento-es',
#  'https://www.pagina12.com.ar/298084-round-de-conocimiento-y-autocritica',
#  'https://www.pagina12.com.ar/298096-crece-la-liquidacion-de-exportaciones',
#  'https://www.pagina12.com.ar/298132-a-la-mesa-le-falta-una-pata',
#  'https://www.pagina12.com.ar/298136-el-dolar-paralelo-mete-presion-167-pesos',
#  'https://www.pagina12.com.ar/298140-las-expectativas-de-la-economia-real-se-moderan',
#  'https://www.pagina12.com.ar/298150-como-frenar-la-devaluacion',
#  'https://www.pagina12.com.ar/295282-jubilados-octubre-2020-el-cronograma-de-pago-completo-de-la-',
#  'https://www.pagina12.com.ar/298099-encrucijadas-el-coronavirus-y-los-dos-mundos-posibles',
#  'https://www.pagina12.com.ar/298059-banco-mundial-la-economia-argentina-caera-12-3-por-ciento-es',
#  'https://www.pagina12.com.ar/298084-round-de-conocimiento-y-autocritica',
#  'https://www.pagina12.com.ar/298096-crece-la-liquidacion-de-exportaciones',
#  'https://www.pagina12.com.ar/298132-a-la-mesa-le-falta-una-pata',
#  'https://www.pagina12.com.ar/298136-el-dolar-paralelo-mete-presion-167-pesos',
#  'https://www.pagina12.com.ar/298140-las-expectativas-de-la-economia-real-se-moderan',
#  'https://www.pagina12.com.ar/298150-como-frenar-la-devaluacion',
#  'https://www.pagina12.com.ar/295282-jubilados-octubre-2020-el-cronograma-de-pago-completo-de-la-',
#  'https://www.pagina12.com.ar/297414-mujeres',
#  'https://www.pagina12.com.ar/298059-banco-mundial-la-economia-argentina-caera-12-3-por-ciento-es',
#  'https://www.pagina12.com.ar/298084-round-de-conocimiento-y-autocritica',
#  'https://www.pagina12.com.ar/298096-crece-la-liquidacion-de-exportaciones',
#  'https://www.pagina12.com.ar/298132-a-la-mesa-le-falta-una-pata',
#  'https://www.pagina12.com.ar/298136-el-dolar-paralelo-mete-presion-167-pesos',
#  'https://www.pagina12.com.ar/298140-las-expectativas-de-la-economia-real-se-moderan',
#  'https://www.pagina12.com.ar/298150-como-frenar-la-devaluacion',
#  'https://www.pagina12.com.ar/295282-jubilados-octubre-2020-el-cronograma-de-pago-completo-de-la-',
#  'https://www.pagina12.com.ar/297805-roberto-abel-rivelli-y-elba-beatriz-pirola-gustavo-javier-fe',
#  'https://www.pagina12.com.ar/298059-banco-mundial-la-economia-argentina-caera-12-3-por-ciento-es',
#  'https://www.pagina12.com.ar/298084-round-de-conocimiento-y-autocritica',
#  'https://www.pagina12.com.ar/298096-crece-la-liquidacion-de-exportaciones',
#  'https://www.pagina12.com.ar/298132-a-la-mesa-le-falta-una-pata',
#  'https://www.pagina12.com.ar/298136-el-dolar-paralelo-mete-presion-167-pesos',
#  'https://www.pagina12.com.ar/298140-las-expectativas-de-la-economia-real-se-moderan',
#  'https://www.pagina12.com.ar/298150-como-frenar-la-devaluacion',
#  'https://www.pagina12.com.ar/295282-jubilados-octubre-2020-el-cronograma-de-pago-completo-de-la-',
#  'https://www.pagina12.com.ar/244746-reflota-el-proyecto-de-pickup-en-argentina',
#  'https://www.pagina12.com.ar/298059-banco-mundial-la-economia-argentina-caera-12-3-por-ciento-es',
#  'https://www.pagina12.com.ar/298084-round-de-conocimiento-y-autocritica',
#  'https://www.pagina12.com.ar/298096-crece-la-liquidacion-de-exportaciones',
#  'https://www.pagina12.com.ar/298132-a-la-mesa-le-falta-una-pata',
#  'https://www.pagina12.com.ar/298136-el-dolar-paralelo-mete-presion-167-pesos',
#  'https://www.pagina12.com.ar/298140-las-expectativas-de-la-economia-real-se-moderan',
#  'https://www.pagina12.com.ar/298150-como-frenar-la-devaluacion',
#  'https://www.pagina12.com.ar/295282-jubilados-octubre-2020-el-cronograma-de-pago-completo-de-la-',
#  'https://www.pagina12.com.ar/298237-volvieron-a-marchar-por-la-mujer-encontrada-muerta-en-cerril',
#  'https://www.pagina12.com.ar/298059-banco-mundial-la-economia-argentina-caera-12-3-por-ciento-es',
#  'https://www.pagina12.com.ar/298084-round-de-conocimiento-y-autocritica',
#  'https://www.pagina12.com.ar/298096-crece-la-liquidacion-de-exportaciones',
#  'https://www.pagina12.com.ar/298132-a-la-mesa-le-falta-una-pata',
#  'https://www.pagina12.com.ar/298136-el-dolar-paralelo-mete-presion-167-pesos',
#  'https://www.pagina12.com.ar/298140-las-expectativas-de-la-economia-real-se-moderan',
#  'https://www.pagina12.com.ar/298150-como-frenar-la-devaluacion',
#  'https://www.pagina12.com.ar/295282-jubilados-octubre-2020-el-cronograma-de-pago-completo-de-la-',
#  'https://www.pagina12.com.ar/240289-el-brindis-con-los-socios-de-pagina-12',
#  'https://www.pagina12.com.ar/298059-banco-mundial-la-economia-argentina-caera-12-3-por-ciento-es',
#  'https://www.pagina12.com.ar/298084-round-de-conocimiento-y-autocritica',
#  'https://www.pagina12.com.ar/298096-crece-la-liquidacion-de-exportaciones',
#  'https://www.pagina12.com.ar/298132-a-la-mesa-le-falta-una-pata',
#  'https://www.pagina12.com.ar/298136-el-dolar-paralelo-mete-presion-167-pesos',
#  'https://www.pagina12.com.ar/298140-las-expectativas-de-la-economia-real-se-moderan',
#  'https://www.pagina12.com.ar/298150-como-frenar-la-devaluacion',
#  'https://www.pagina12.com.ar/295282-jubilados-octubre-2020-el-cronograma-de-pago-completo-de-la-',
#  'https://www.pagina12.com.ar/298015-quien-es-arcasur',
#  'https://www.pagina12.com.ar/298059-banco-mundial-la-economia-argentina-caera-12-3-por-ciento-es',
#  'https://www.pagina12.com.ar/298084-round-de-conocimiento-y-autocritica',
#  'https://www.pagina12.com.ar/298096-crece-la-liquidacion-de-exportaciones',
#  'https://www.pagina12.com.ar/298132-a-la-mesa-le-falta-una-pata',
#  'https://www.pagina12.com.ar/298136-el-dolar-paralelo-mete-presion-167-pesos',
#  'https://www.pagina12.com.ar/298140-las-expectativas-de-la-economia-real-se-moderan',
#  'https://www.pagina12.com.ar/298150-como-frenar-la-devaluacion',
#  'https://www.pagina12.com.ar/295282-jubilados-octubre-2020-el-cronograma-de-pago-completo-de-la-',
#  'https://www.pagina12.com.ar/297016-construir-y-comunicar-sororidad',
#  'https://www.pagina12.com.ar/298059-banco-mundial-la-economia-argentina-caera-12-3-por-ciento-es',
#  'https://www.pagina12.com.ar/298084-round-de-conocimiento-y-autocritica',
#  'https://www.pagina12.com.ar/298096-crece-la-liquidacion-de-exportaciones',
#  'https://www.pagina12.com.ar/298132-a-la-mesa-le-falta-una-pata',
#  'https://www.pagina12.com.ar/298136-el-dolar-paralelo-mete-presion-167-pesos',
#  'https://www.pagina12.com.ar/298140-las-expectativas-de-la-economia-real-se-moderan',
#  'https://www.pagina12.com.ar/298150-como-frenar-la-devaluacion',
#  'https://www.pagina12.com.ar/295282-jubilados-octubre-2020-el-cronograma-de-pago-completo-de-la-']

# %% [markdown]
# ## Comenzar el scraper por cada link obtenido

# %%
data = []
for i, nota in enumerate(notas):
    print(f'Scrapeando , nota{i}/{len(notas)}')
